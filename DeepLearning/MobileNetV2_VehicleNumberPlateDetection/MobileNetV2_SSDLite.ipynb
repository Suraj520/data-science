# %% [markdown]
# # Topic of the Opensource Project : Object Detection using MobileNet v2 SSD (SSDlite)
# >
# > This Notebook covers training an Object detection network using SSDLite on Indian Vehicle Number Plate dataset downloaded from [Kaggle](https://https://www.kaggle.com/dataturks/vehicle-number-plate-detection)

# %% [markdown]
# > # Step 1_a.
# > > Environment Setup and Dataset acquisition followed by pre-processing.

# %%
#Checking the configuration of the run-time
# !nvidia-smi
# Out:
# Wed Mar  3 06:28:34 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#importing modules
import numpy as np
import tensorflow.keras as keras
from keras.layers import Conv2D, BatchNormalization, Add,MaxPool2D, ZeroPadding2D,DepthwiseConv2D, ReLU, Input,AveragePooling2D, GlobalAveragePooling2D,Dense, Activation
from keras.activations import sigmoid,relu
from keras.optimizers import SGD, Adam, RMSprop
from keras.models import Sequential,Model
from keras.preprocessing.image import load_img,array_to_img, img_to_array, ImageDataGenerator
import os
import pandas as pd
from PIL import Image
import urllib
import tqdm
import cv2
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import train_test_split

# %%
#loading the dataset via Google drive
Path = '/content/drive/MyDrive/Colab Notebooks/Dataset'
os.chdir(Path)
# !ls
# Out:
#  ALPR_Checkpoint    fruits_dataset.zip	        Test2.jpg   train_zip
#  apple_2.jpg	    Indian_Number_plates.json   Test3.jpg
#  checkpoint	    Test1.jpg		        Test4.jpg
#  FruitDetector.h5  'Test2 (1).jpg'	        test_zip

# %%
#reading json file using pandas
df = pd.read_json('Indian_Number_plates.json', lines=True)

# %%
df.head()
# Out:
#                                              content  ... extras
# 0  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 1  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 2  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 3  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 4  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
#
# [5 rows x 3 columns]

# %%
#printing the head and keys of the dataset
print(df.head())
print(df.keys())
#clearly we can see that the dataframe has 3 keys known as 'content' which is the URL of the image, 'annotation which contains the ROI of bbx' and 'extras' being the metadata
print(df['content'])
# Out:
#                                              content  ... extras
# 0  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 1  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 2  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 3  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 4  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
#
# [5 rows x 3 columns]
# Index(['content', 'annotation', 'extras'], dtype='object')
# 0      http://com.dataturks.a96-i23.open.s3.amazonaws...
# 1      http://com.dataturks.a96-i23.open.s3.amazonaws...
# 2      http://com.dataturks.a96-i23.open.s3.amazonaws...
# 3      http://com.dataturks.a96-i23.open.s3.amazonaws...
# 4      http://com.dataturks.a96-i23.open.s3.amazonaws...
#                              ...
# 232    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 233    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 234    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 235    http://com.dataturks.a96-i23.open.s3.amazonaws...
# 236    http://com.dataturks.a96-i23.open.s3.amazonaws...
# Name: content, Length: 237, dtype: object

# %%
def process_create_train_val_set(dataframe):
  #create a dictionary for the dataset i.e Image_data, xmin, ymin, xmax, ymax, class_id
  Images, coordinates = [],[]
  #Now iterating through the rows in the dataframe
  image_counter=0
  #Assuming each of the links in the dataframe are working
  for index, sample in tqdm.tqdm_notebook(dataframe.iterrows()):
    image = urllib.request.urlopen(sample['content'])
    #now opening the image and converting it to 3 channel RGB
    image = Image.open(image)
    image = image.convert('RGB')
    #capturing the original dimensions of the image for coordinate scaling at a later stage
    w,h,_ = np.shape(image)
    image_data = image.resize((224,224))
    #converting the image to array
    image_data = img_to_array(image_data)
    #appending this data in the dictionary
    Images.append(image_data)
    #till this point, we have our image data
    #fetching x min, xmax, ymin and ymax from annotation key of the above dataframe
    Coordinates = sample['annotation']
    #Appending normalized coordinates as per the new aspect ratio of resized image
    #print(int(round(Coordinates[0]['points'][1]['x']*1*(224))))
    x1 = int(round(Coordinates[0]['points'][0]['x']*224))
    y1= int(round((Coordinates[0]['points'][0]['y']*224)))
    x2 = (int(round((Coordinates[0]['points'][1]['x']*224))))
    y2 = (int(round((Coordinates[0]['points'][1]['y']*224))))
    coordinates.append([x1,y1,x2-x1,y2-y1])
    #incrementing the counter by 1
    image_counter+=1
  return Images,coordinates
  #return((Dataset['Image_data']))

#running the main function
Images,coordinates = process_create_train_val_set(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
#checking the length of each list
print(np.shape(Images))
print(np.shape(coordinates))
# Out:
# (237, 224, 224, 3)
# (237, 4)

# %% [markdown]
# # Data Validation Stage
#  > In this Stage, We will monitor the resized images and their bounding box coordinates by plotting few random samples from the dataset.

# %%
def plot_annotated_image(Images, coordinates):
  #generate 5_random indices
  idx=[]
  for i in range(5):
    idx.append(random.randint(1,30))
  #now plot these random images
  for id in idx:
    #converting array to image.
    image = np.array(array_to_img(Images[id]))
    #converting rgb image to bgr
    im_arr = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    #print((Dataset['xmin'][id],Dataset['ymin'][id]),(Dataset['xmax'][id],Dataset['ymax'][id]))
    #Drawing bounding box
    cv2.rectangle(im_arr,(coordinates[id][0],coordinates[id][1],coordinates[id][2],coordinates[id][3]),(255,0,0), 3)
    #displaying the image with bounding box
    plt.imshow(im_arr)
    plt.show()
plot_annotated_image(Images,coordinates)

# %% [markdown]
# # Analysis result
# > - We can observe that our coordinates and images are proper, now we can move towards the final step of Data processing pipeline i.e train and val split of the dataset

# %%
#creating split as 70-30% ratio
train_image,val_image,train_coordinates,val_coordinates = train_test_split(Images,coordinates,test_size=0.3, shuffle=True)

# %%
#converting each list to numpy array
train_image = np.asarray(train_image)
val_image = np.asarray(val_image)
train_coordinates = np.asarray(train_coordinates)
val_coordinates = np.asarray(val_coordinates)

print("Number of training image samples",np.shape(train_image))
print("Number of training coordinate samples",np.shape(train_coordinates))
print("Number of validation image samples",np.shape(val_image))
print("Number of validation coordinate samples",np.shape(val_coordinates))
# Out:
# Number of training image samples (165, 224, 224, 3)
# Number of training coordinate samples (165, 4)
# Number of validation image samples (72, 224, 224, 3)
# Number of validation coordinate samples (72, 4)

# %%
#validating splitted train and test data

print("Train Split Images")
plot_annotated_image(train_image, train_coordinates)
print("Val Split Images")
plot_annotated_image(val_image, val_coordinates)
# Out:
# Train Split Images
# Val Split Images

# %% [markdown]
# # Step 1.b
# Using Data generators

# %%
print(df.head())
df = df.sample(frac = 1)
print(df.head())
# Out:
#                                              content  ... extras
# 0  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 1  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 2  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 3  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 4  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
#
# [5 rows x 3 columns]
#                                                content  ... extras
# 58   http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 159  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 116  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 93   http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
# 155  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...    NaN
#
# [5 rows x 3 columns]

# %%
#shuffling the dataframe
# def shuffle(dataframe_samples):
#   return dataframe_samples.sample(frac=1)

#This is slow as it gives url error
# # A data generator loads data in batches and yields the images and their corresponding labels(annotations and class_labels)
# def html_based_generator(samples, batch_size = 32):
#     #samples = dataframe out here
#     num_samples = len(samples)
#     #endlessly iterate the generator
#     while True:
#       #shuffling the samples
#       shuffle(samples)
#       for mini_batch in range(0, num_samples,batch_size):
#           batch_samples = samples[mini_batch:mini_batch+batch_size]
#           #Initialise empty list for I/0 of network, here Image, labels and coordniates
#           Images, coordinates,labels = [],[],[]
#           for image_url, bbox in zip(batch_samples['content'], batch_samples['annotation']):
#             #load image and append them in Images
#             image = urllib.request.urlopen(image_url)
#             #now opening the image and converting it to 3 channel RGB
#             image = Image.open(image)
#             image = image.convert('RGB')
#             #capturing the original dimensions of the image for coordinate scaling at a later stage
#             w,h,_ = np.shape(image)
#             image_data = image.resize((224,224))
#             #converting the image to array
#             image_data = img_to_array(image_data)
#             #appending this data in the dictionary
#             Images.append(image_data)
#             #load the coordinates and append them in Coordinates]
#             #Appending normalized coordinates as per the new aspect ratio of resized image
#             #print(int(round(Coordinates[0]['points'][1]['x']*1*(224))))
#             x1 = int(round(bbox[0]['points'][0]['x']*224))
#             y1= int(round((bbox[0]['points'][0]['y']*224)))
#             x2 = (int(round((bbox[0]['points'][1]['x']*224))))
#             y2 = (int(round((bbox[0]['points'][1]['y']*224))))
#             coordinates.append([x1,y1,x2-x1,y2-y1])
#             #load the labels and append them in Labels
#             #since this is only single class statement
#             labels.append(0)
        
#           #convert each list to numpy arrays to ensure that they get processed by fit function
#           Images = np.asarray(Images)
#           coordinates = np.asarray(coordinates)
#           labels = np.asarray(labels)
#           #yeild the generator array objects

#           yield Images,coordinates,labels

#shuffle function for lists
def shuffle_data(images,coordinates):
  c = list(zip(images, coordinates))
  images, coordinates = random.shuffle(c)
  return images,coordinates

# better version of data generator with data samples which takes in images and coordinates instead of dataframes
def generator(images,coordinates, batch_size = 32):
    #samples = list of images and coordinates; assuming them to have equal number of images
    num_samples = len(images)
    #endlessly iterate the generator
    while True:
      #shuffling the samples
      #images,coordinates = shuffle_data(images,coordinates)
      for image_mini_batch, coordinates_mini_batch in zip(range(0, num_samples,batch_size),range(0, num_samples,batch_size)):
          image_batch_samples = images[image_mini_batch:image_mini_batch+batch_size]
          coordinate_batch_samples = coordinates[coordinates_mini_batch:coordinates_mini_batch+batch_size]
          #Initialise empty list for I/0 of network, here Image, labels and coordniates
          Images, coordinates,labels = [],[],[]
          for image, bbox in zip(image_batch_samples, coordinate_batch_samples):
            #append them to Images directly
            Images.append(image)
            #load the coordinates and append them in Coordinates]
            #Appending normalized coordinates as per the new aspect ratio of resized image
            #print(int(round(Coordinates[0]['points'][1]['x']*1*(224))))
            coordinates.append(bbox)
            #label = 0 so not changing
            
        
          #convert each list to numpy arrays to ensure that they get processed by fit function
          Images = np.asarray(Images)
          coordinates = np.asarray(coordinates)
          labels = np.asarray(labels)
          #yeild the generator array objects

          yield Images,coordinates




#testing datagenerator
train_generator = generator(Images,coordinates)

# %%
#checking the data given by image generator
idx=0
for image,coordinate in train_generator:
    #plotting for 2 cycles of data generator
    if idx<=2:
      try:
        plot_annotated_image(image, coordinate)
      except IndexError:
        print("Skipping")
      idx+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-951127a04e14> in <module>()
#       1 #checking the data given by image generator
#       2 idx=0
# ----> 3 for image,coordinate in train_generator:
#       4     #plotting for 2 cycles of data generator
#       5     if idx<=2:
#
# NameError: name 'train_generator' is not defined

# %% [markdown]
# ### Outcome
# Great, we have our image data generator also working!

# %% [markdown]
# #Conclusion of Data Engineering
# > Till this point our data is perfectly segmented into train and val split along with 6 indices storing image_data, 4 coordinates and class_id
# > Also in part 2, we have made our image data generator to work pretty fine too.

# %% [markdown]
# ## Step2_a
# > > Deep Learning Network Architecture (Mobilenet V2 SSD from scratch)

# %%
def SSDLite(input_shape, coordinates):
  #bottleneck block
  #bottle neck block
  def bottleneck_block(input_tensor, squeezed_filters, alpha=1.0, expansion_factor=6, stride = 1):
    print("input shape", np.shape(input_tensor))
    in_channels = np.shape(input_tensor)[-1]
    out = Conv2D(expansion_factor * in_channels, (1,1))(input_tensor)
    out = BatchNormalization()(out)
    out = ReLU(max_value=6)(out)
    if stride ==2:
      out = ZeroPadding2D(padding=(1,1))(out)
    out = DepthwiseConv2D((3,3))(out)
    out = BatchNormalization()(out)
    out = ReLU(max_value=6)(out)
    squeezed_filters = int(squeezed_filters * alpha)
    out = Conv2D(squeezed_filters, (1,1), padding='same')(out)
    out = BatchNormalization()(out)
    #hacky fix below :(
    out = ZeroPadding2D(padding=(1,1))(out)
    print("output shape", np.shape(out))
    if in_channels == squeezed_filters and stride ==1:
      output= Add()([out, input_tensor])
      return output
    return out
    
  Model_input = Input(input_shape)
  x = Conv2D(32,3,2,padding='same')(Model_input)
  #Batch normalisation and ReLU activation after each convolution are mandatory for non-linearity and avoiding co-variance shift
  x = BatchNormalization()(x)
  x = ReLU(max_value=6)(x)
  #now stacking depthwise conv block as per Mobilenet paper
  x = bottleneck_block(x,16,expansion_factor=1)
  # As n = 2
  x = bottleneck_block(x,24, stride=2)
  x = bottleneck_block(x,24, stride=1)
  # as n =3
  for _ in range(3):
    x = bottleneck_block(x,32,stride=1)
  # as n = 4
  for _ in range(4):
    x = bottleneck_block(x,64, stride =1)
  # as n = 3
  for _ in range(3):
    x = bottleneck_block(x,96, stride=1)
  # n =3
  for _ in range(3):
    x = bottleneck_block(x,160,stride=1)
  # as n = 1
  x = bottleneck_block(x,320, stride =1)
  # as n = 1
  x = Conv2D(1280, (1,1))(x)
  x = BatchNormalization()(x)
  x = ReLU(max_value=6)(x)
  #Adding average pooling 2D layer
  x = GlobalAveragePooling2D()(x)
  # full connected i.e dense layer
  bbox = Dense(coordinates, activation='linear', name="regressor")(x)
  model = Model(Model_input, bbox)
  return model

# %%
Input_shape = 224,224,3
num_classes = 1
coordinates = 4
model = SSDLite(Input_shape,coordinates)
model.summary()
# Out:
# input shape (None, 112, 112, 32)
# output shape (None, 112, 112, 16)
# input shape (None, 112, 112, 16)
# output shape (None, 114, 114, 24)
# input shape (None, 114, 114, 24)
# output shape (None, 114, 114, 24)
# input shape (None, 114, 114, 24)
# output shape (None, 114, 114, 32)
# input shape (None, 114, 114, 32)
# output shape (None, 114, 114, 32)
# input shape (None, 114, 114, 32)
# output shape (None, 114, 114, 32)
# input shape (None, 114, 114, 32)
# output shape (None, 114, 114, 64)
# input shape (None, 114, 114, 64)
# output shape (None, 114, 114, 64)
# input shape (None, 114, 114, 64)
# output shape (None, 114, 114, 64)
# input shape (None, 114, 114, 64)
# output shape (None, 114, 114, 64)
# input shape (None, 114, 114, 64)
# output shape (None, 114, 114, 96)
# input shape (None, 114, 114, 96)
# output shape (None, 114, 114, 96)
# input shape (None, 114, 114, 96)
# output shape (None, 114, 114, 96)
# input shape (None, 114, 114, 96)
# output shape (None, 114, 114, 160)
# input shape (None, 114, 114, 160)
# output shape (None, 114, 114, 160)
# input shape (None, 114, 114, 160)
# output shape (None, 114, 114, 160)
# input shape (None, 114, 114, 160)
# output shape (None, 114, 114, 320)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 112, 112, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 32) 1056        re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 112, 112, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 110, 110, 32) 320         re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 110, 110, 32) 128         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 110, 110, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 110, 110, 16) 528         re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 110, 110, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 112, 112, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 96) 1632        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 96) 384         conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 112, 112, 96) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 114, 114, 96) 0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 112, 112, 96) 960         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 112, 112, 96) 384         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 112, 112, 96) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 24) 2328        re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 112, 112, 24) 96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 114, 114, 24) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 114, 114, 144 3600        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 114, 114, 144 576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 114, 114, 144 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 112, 112, 144 1440        re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 112, 112, 144 576         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 112, 112, 144 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 112, 112, 24) 3480        re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 112, 112, 24) 96          conv2d_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 114, 114, 24) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 114, 114, 24) 0           zero_padding2d_3[0][0]
#                                                                  zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 114, 114, 144 3600        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 114, 114, 144 576         conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 114, 114, 144 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 112, 112, 144 1440        re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 112, 112, 144 576         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 112, 112, 144 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 112, 112, 32) 4640        re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 112, 112, 32) 128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 114, 114, 32) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 114, 114, 192 6336        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 114, 114, 192 768         conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 114, 114, 192 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 112, 112, 192 1920        re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 112, 112, 192 768         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 112, 112, 192 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 112, 112, 32) 6176        re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 112, 112, 32) 128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 114, 114, 32) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 114, 114, 32) 0           zero_padding2d_5[0][0]
#                                                                  zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 114, 114, 192 6336        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 114, 114, 192 768         conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 114, 114, 192 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 112, 112, 192 1920        re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 112, 112, 192 768         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 112, 112, 192 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 112, 112, 32) 6176        re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 112, 112, 32) 128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 114, 114, 32) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 114, 114, 32) 0           zero_padding2d_6[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 114, 114, 192 6336        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 114, 114, 192 768         conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 114, 114, 192 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 112, 112, 192 1920        re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 112, 112, 192 768         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 112, 112, 192 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 112, 112, 64) 12352       re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 112, 112, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 114, 114, 64) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 114, 114, 384 24960       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 114, 114, 384 1536        conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 114, 114, 384 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 112, 112, 384 3840        re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 112, 112, 384 1536        depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 112, 112, 384 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 112, 112, 64) 24640       re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 112, 112, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 114, 114, 64) 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 114, 114, 64) 0           zero_padding2d_8[0][0]
#                                                                  zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 114, 114, 384 24960       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 114, 114, 384 1536        conv2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 114, 114, 384 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 112, 112, 384 3840        re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 112, 112, 384 1536        depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 112, 112, 384 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 112, 112, 64) 24640       re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 112, 112, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 114, 114, 64) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 114, 114, 64) 0           zero_padding2d_9[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 114, 114, 384 24960       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 114, 114, 384 1536        conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 114, 114, 384 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 112, 112, 384 3840        re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 112, 112, 384 1536        depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 112, 112, 384 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 112, 112, 64) 24640       re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 112, 112, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 114, 114, 64) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 114, 114, 64) 0           zero_padding2d_10[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 114, 114, 384 24960       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 114, 114, 384 1536        conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 114, 114, 384 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 112, 112, 384 3840        re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 112, 112, 384 1536        depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 112, 112, 384 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 112, 112, 96) 36960       re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 112, 112, 96) 384         conv2d_22[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 114, 114, 96) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 114, 114, 576 55872       zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 114, 114, 576 2304        conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 114, 114, 576 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 112, 112, 576 5760        re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 112, 112, 576 2304        depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 112, 112, 576 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 112, 112, 96) 55392       re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 112, 112, 96) 384         conv2d_24[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 114, 114, 96) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 114, 114, 96) 0           zero_padding2d_12[0][0]
#                                                                  zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 114, 114, 576 55872       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 114, 114, 576 2304        conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 114, 114, 576 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 112, 112, 576 5760        re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 112, 112, 576 2304        depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 112, 112, 576 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 112, 112, 96) 55392       re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 112, 112, 96) 384         conv2d_26[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 114, 114, 96) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 114, 114, 96) 0           zero_padding2d_13[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 114, 114, 576 55872       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 114, 114, 576 2304        conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 114, 114, 576 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 112, 112, 576 5760        re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 112, 112, 576 2304        depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 112, 112, 576 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 112, 112, 160 92320       re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 112, 112, 160 640         conv2d_28[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 114, 114, 160 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 114, 114, 960 154560      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 114, 114, 960 3840        conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 114, 114, 960 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 112, 112, 960 9600        re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 112, 112, 960 3840        depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 112, 112, 960 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 112, 112, 160 153760      re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 112, 112, 160 640         conv2d_30[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 114, 114, 160 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 114, 114, 160 0           zero_padding2d_15[0][0]
#                                                                  zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 114, 114, 960 154560      add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 114, 114, 960 3840        conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 114, 114, 960 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 112, 112, 960 9600        re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 112, 112, 960 3840        depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 112, 112, 960 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 112, 112, 160 153760      re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 112, 112, 160 640         conv2d_32[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 114, 114, 160 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 114, 114, 160 0           zero_padding2d_16[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 114, 114, 960 154560      add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 114, 114, 960 3840        conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 114, 114, 960 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 112, 112, 960 9600        re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 112, 112, 960 3840        depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 112, 112, 960 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 112, 112, 320 307520      re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 112, 112, 320 1280        conv2d_34[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 114, 114, 320 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 114, 114, 128 410880      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 114, 114, 128 5120        conv2d_35[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 114, 114, 128 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           re_lu_35[0][0]
# __________________________________________________________________________________________________
# regressor (Dense)               (None, 4)            5124        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 2,281,348
# Trainable params: 2,247,172
# Non-trainable params: 34,176
# __________________________________________________________________________________________________

# %%
#compiling model with loss functions
init_lr = 0.1
epochs = 20
opt =RMSprop(lr=0.1, decay=0.9, momentum=0.9)
model.compile(optimizer=opt, 
              loss={'regressor':'mse'}, 
              metrics={'regressor':'accuracy'})

# %%
# training without generators
from tensorflow.keras.callbacks import ModelCheckpoint
callbacks = [ModelCheckpoint("/content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint", monitor='val_loss')]
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
history = model.fit(train_image,train_coordinates,batch_size = 4,epochs = 100,verbose=1,callbacks=[callbacks], validation_data=(val_image, val_coordinates),shuffle=True, validation_batch_size=32 ,use_multiprocessing=True,workers=12 )
# Out:
# Epoch 1/100
# 42/42 [==============================] - 90s 1s/step - loss: 7558.2624 - accuracy: 0.5408 - val_loss: 23306308.0000 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 2/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1647.6993 - accuracy: 0.5923 - val_loss: 22233252.0000 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 3/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1501.9463 - accuracy: 0.7084 - val_loss: 19490246.0000 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 4/100
# 42/42 [==============================] - 42s 995ms/step - loss: 1512.6967 - accuracy: 0.6368 - val_loss: 7355780.0000 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 5/100
# 42/42 [==============================] - 41s 986ms/step - loss: 1703.4886 - accuracy: 0.5830 - val_loss: 325296.2500 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 6/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1552.9764 - accuracy: 0.6267 - val_loss: 10813.2373 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 7/100
# 42/42 [==============================] - 42s 999ms/step - loss: 1865.3580 - accuracy: 0.5720 - val_loss: 4438.3145 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 8/100
# 42/42 [==============================] - 42s 991ms/step - loss: 1626.3148 - accuracy: 0.6189 - val_loss: 2811.4966 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 9/100
# 42/42 [==============================] - 41s 985ms/step - loss: 1485.3737 - accuracy: 0.5899 - val_loss: 2146.6902 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 10/100
# 42/42 [==============================] - 41s 989ms/step - loss: 1630.7683 - accuracy: 0.5623 - val_loss: 1929.0927 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 11/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1514.0780 - accuracy: 0.5398 - val_loss: 1866.2291 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 12/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1456.7423 - accuracy: 0.6134 - val_loss: 1820.2454 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 13/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1558.9979 - accuracy: 0.6276 - val_loss: 1733.0161 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 14/100
# 42/42 [==============================] - 42s 998ms/step - loss: 1463.4567 - accuracy: 0.5704 - val_loss: 1789.9274 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 15/100
# 42/42 [==============================] - 42s 992ms/step - loss: 1774.0014 - accuracy: 0.5864 - val_loss: 1758.9004 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 16/100
# 42/42 [==============================] - 42s 999ms/step - loss: 1347.9674 - accuracy: 0.6515 - val_loss: 1769.6460 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 17/100
# 42/42 [==============================] - 42s 1000ms/step - loss: 1699.2341 - accuracy: 0.6035 - val_loss: 1747.0415 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 18/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1553.1304 - accuracy: 0.6087 - val_loss: 1763.1401 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 19/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1509.4983 - accuracy: 0.5738 - val_loss: 1767.7153 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 20/100
# 42/42 [==============================] - 42s 995ms/step - loss: 1553.2573 - accuracy: 0.5736 - val_loss: 1768.2479 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 21/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1746.9221 - accuracy: 0.5760 - val_loss: 1736.3680 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 22/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1573.8982 - accuracy: 0.6765 - val_loss: 1713.8312 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 23/100
# 42/42 [==============================] - 41s 987ms/step - loss: 1743.7372 - accuracy: 0.5936 - val_loss: 1738.1848 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 24/100
# 42/42 [==============================] - 41s 987ms/step - loss: 1670.8161 - accuracy: 0.5406 - val_loss: 1756.1346 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 25/100
# 42/42 [==============================] - 42s 991ms/step - loss: 1434.7332 - accuracy: 0.6046 - val_loss: 1701.5464 - val_accuracy: 0.6667
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 26/100
# 42/42 [==============================] - 42s 995ms/step - loss: 1608.6153 - accuracy: 0.6276 - val_loss: 1687.6300 - val_accuracy: 0.6667
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 27/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1895.3981 - accuracy: 0.5082 - val_loss: 1679.7611 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 28/100
# 42/42 [==============================] - 42s 1000ms/step - loss: 1310.8167 - accuracy: 0.6501 - val_loss: 1688.2469 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 29/100
# 42/42 [==============================] - 42s 998ms/step - loss: 1299.1911 - accuracy: 0.6731 - val_loss: 1670.3911 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 30/100
# 42/42 [==============================] - 42s 997ms/step - loss: 1564.8690 - accuracy: 0.6163 - val_loss: 1664.4850 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 31/100
# 42/42 [==============================] - 42s 1s/step - loss: 1608.7873 - accuracy: 0.5669 - val_loss: 1668.7223 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 32/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1736.8376 - accuracy: 0.5616 - val_loss: 1667.6016 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 33/100
# 42/42 [==============================] - 42s 998ms/step - loss: 1358.0588 - accuracy: 0.6361 - val_loss: 1667.8717 - val_accuracy: 0.6389
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 34/100
# 42/42 [==============================] - 42s 992ms/step - loss: 1433.2620 - accuracy: 0.6085 - val_loss: 1649.1415 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 35/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1523.3228 - accuracy: 0.6294 - val_loss: 1639.5072 - val_accuracy: 0.6667
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 36/100
# 42/42 [==============================] - 42s 991ms/step - loss: 1437.9745 - accuracy: 0.6019 - val_loss: 1668.3248 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 37/100
# 42/42 [==============================] - 42s 990ms/step - loss: 1336.7158 - accuracy: 0.6378 - val_loss: 1661.5088 - val_accuracy: 0.6250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 38/100
# 42/42 [==============================] - 42s 997ms/step - loss: 1754.3146 - accuracy: 0.5930 - val_loss: 1627.4225 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 39/100
# 42/42 [==============================] - 41s 988ms/step - loss: 1546.6255 - accuracy: 0.6031 - val_loss: 1691.2413 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 40/100
# 42/42 [==============================] - 42s 997ms/step - loss: 1554.1004 - accuracy: 0.6538 - val_loss: 1665.4183 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 41/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1640.4585 - accuracy: 0.6963 - val_loss: 1621.4861 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 42/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1637.8939 - accuracy: 0.6255 - val_loss: 1645.1471 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 43/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1399.2889 - accuracy: 0.6215 - val_loss: 1620.3884 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 44/100
# 42/42 [==============================] - 42s 991ms/step - loss: 1699.5167 - accuracy: 0.6381 - val_loss: 1621.5090 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 45/100
# 42/42 [==============================] - 42s 992ms/step - loss: 1378.5910 - accuracy: 0.6668 - val_loss: 1603.5149 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 46/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1509.4200 - accuracy: 0.6456 - val_loss: 1611.6151 - val_accuracy: 0.7361
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 47/100
# 42/42 [==============================] - 42s 999ms/step - loss: 1518.4619 - accuracy: 0.6163 - val_loss: 1613.1689 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 48/100
# 42/42 [==============================] - 42s 1s/step - loss: 1816.0694 - accuracy: 0.6281 - val_loss: 1604.7261 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 49/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1483.4855 - accuracy: 0.6127 - val_loss: 1703.4766 - val_accuracy: 0.6667
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 50/100
# 42/42 [==============================] - 42s 992ms/step - loss: 1593.4475 - accuracy: 0.7207 - val_loss: 1688.9478 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 51/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1504.3723 - accuracy: 0.6498 - val_loss: 1652.0265 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 52/100
# 42/42 [==============================] - 42s 992ms/step - loss: 1488.8546 - accuracy: 0.6877 - val_loss: 1657.8320 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 53/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1749.7721 - accuracy: 0.6573 - val_loss: 1631.5586 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 54/100
# 42/42 [==============================] - 42s 999ms/step - loss: 1398.9429 - accuracy: 0.7012 - val_loss: 1623.4147 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 55/100
# 42/42 [==============================] - 41s 986ms/step - loss: 1290.1847 - accuracy: 0.6907 - val_loss: 1631.4121 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 56/100
# 42/42 [==============================] - 42s 995ms/step - loss: 1484.7473 - accuracy: 0.6663 - val_loss: 1605.8501 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 57/100
# 42/42 [==============================] - 42s 989ms/step - loss: 1430.4267 - accuracy: 0.6960 - val_loss: 1596.9191 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 58/100
# 42/42 [==============================] - 42s 991ms/step - loss: 1344.3807 - accuracy: 0.7238 - val_loss: 1598.3158 - val_accuracy: 0.7361
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 59/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1675.9184 - accuracy: 0.6653 - val_loss: 1593.2722 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 60/100
# 42/42 [==============================] - 42s 998ms/step - loss: 1394.6653 - accuracy: 0.7090 - val_loss: 1612.4459 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 61/100
# 42/42 [==============================] - 42s 992ms/step - loss: 1295.6496 - accuracy: 0.6739 - val_loss: 1605.9594 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 62/100
# 42/42 [==============================] - 42s 991ms/step - loss: 1432.1609 - accuracy: 0.6747 - val_loss: 1622.7208 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 63/100
# 42/42 [==============================] - 42s 995ms/step - loss: 1329.4276 - accuracy: 0.7085 - val_loss: 1636.8865 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 64/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1407.1777 - accuracy: 0.7035 - val_loss: 1626.6010 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 65/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1627.1640 - accuracy: 0.6484 - val_loss: 1565.7520 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 66/100
# 42/42 [==============================] - 42s 999ms/step - loss: 1400.4963 - accuracy: 0.7202 - val_loss: 1563.8224 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 67/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1605.1929 - accuracy: 0.6927 - val_loss: 1597.4808 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 68/100
# 42/42 [==============================] - 42s 990ms/step - loss: 1367.1093 - accuracy: 0.7211 - val_loss: 1622.7114 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 69/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1280.8686 - accuracy: 0.6873 - val_loss: 1680.3568 - val_accuracy: 0.7361
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 70/100
# 42/42 [==============================] - 42s 995ms/step - loss: 1354.7816 - accuracy: 0.6980 - val_loss: 1631.1655 - val_accuracy: 0.6528
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 71/100
# 42/42 [==============================] - 42s 992ms/step - loss: 1701.6760 - accuracy: 0.6955 - val_loss: 1607.1753 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 72/100
# 42/42 [==============================] - 42s 1000ms/step - loss: 1392.1485 - accuracy: 0.6744 - val_loss: 1606.0532 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 73/100
# 42/42 [==============================] - 42s 997ms/step - loss: 1228.7387 - accuracy: 0.7114 - val_loss: 1606.7350 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 74/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1190.1274 - accuracy: 0.7598 - val_loss: 1580.2653 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 75/100
# 42/42 [==============================] - 42s 998ms/step - loss: 1426.0020 - accuracy: 0.6384 - val_loss: 1601.7991 - val_accuracy: 0.6667
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 76/100
# 42/42 [==============================] - 42s 997ms/step - loss: 1412.3969 - accuracy: 0.6529 - val_loss: 1604.3759 - val_accuracy: 0.6528
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 77/100
# 42/42 [==============================] - 42s 997ms/step - loss: 1173.9541 - accuracy: 0.6958 - val_loss: 1595.3467 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 78/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1331.4042 - accuracy: 0.7051 - val_loss: 1601.0027 - val_accuracy: 0.6528
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 79/100
# 42/42 [==============================] - 42s 998ms/step - loss: 1569.8435 - accuracy: 0.7945 - val_loss: 1613.8722 - val_accuracy: 0.6528
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 80/100
# 42/42 [==============================] - 42s 995ms/step - loss: 1450.4503 - accuracy: 0.6576 - val_loss: 1601.2435 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 81/100
# 42/42 [==============================] - 42s 995ms/step - loss: 1334.1556 - accuracy: 0.7280 - val_loss: 1569.6609 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 82/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1638.4493 - accuracy: 0.6504 - val_loss: 1567.6481 - val_accuracy: 0.6806
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 83/100
# 42/42 [==============================] - 42s 997ms/step - loss: 1540.1129 - accuracy: 0.6810 - val_loss: 1610.6609 - val_accuracy: 0.6528
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 84/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1164.2675 - accuracy: 0.7408 - val_loss: 1573.6088 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 85/100
# 42/42 [==============================] - 42s 992ms/step - loss: 1426.0065 - accuracy: 0.7374 - val_loss: 1575.7216 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 86/100
# 42/42 [==============================] - 42s 989ms/step - loss: 1413.1580 - accuracy: 0.7240 - val_loss: 1583.8300 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 87/100
# 42/42 [==============================] - 42s 991ms/step - loss: 1442.5495 - accuracy: 0.6311 - val_loss: 1539.1812 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 88/100
# 42/42 [==============================] - 41s 989ms/step - loss: 1321.9652 - accuracy: 0.7196 - val_loss: 1545.0210 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 89/100
# 42/42 [==============================] - 42s 991ms/step - loss: 1326.0849 - accuracy: 0.7240 - val_loss: 1524.2169 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 90/100
# 42/42 [==============================] - 42s 998ms/step - loss: 1495.9757 - accuracy: 0.6533 - val_loss: 1549.3547 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 91/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1378.3124 - accuracy: 0.7229 - val_loss: 1538.9498 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 92/100
# 42/42 [==============================] - 42s 999ms/step - loss: 1348.5783 - accuracy: 0.7274 - val_loss: 1533.3783 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 93/100
# 42/42 [==============================] - 42s 997ms/step - loss: 1566.2442 - accuracy: 0.7066 - val_loss: 1541.3336 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 94/100
# 42/42 [==============================] - 42s 998ms/step - loss: 1503.4698 - accuracy: 0.6593 - val_loss: 1575.6155 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 95/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1349.7612 - accuracy: 0.6871 - val_loss: 1548.3048 - val_accuracy: 0.6944
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 96/100
# 42/42 [==============================] - 42s 996ms/step - loss: 1556.5176 - accuracy: 0.7646 - val_loss: 1549.0267 - val_accuracy: 0.7361
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 97/100
# 42/42 [==============================] - 42s 991ms/step - loss: 1351.1354 - accuracy: 0.6570 - val_loss: 1588.4730 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 98/100
# 42/42 [==============================] - 42s 992ms/step - loss: 1643.6812 - accuracy: 0.6596 - val_loss: 1532.1321 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 99/100
# 42/42 [==============================] - 42s 994ms/step - loss: 1537.2169 - accuracy: 0.7106 - val_loss: 1525.0557 - val_accuracy: 0.7222
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets
# Epoch 100/100
# 42/42 [==============================] - 42s 993ms/step - loss: 1237.1956 - accuracy: 0.7651 - val_loss: 1550.2089 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/ALPR_Checkpoint/assets

# %%
#saving the model
model.save("NumberPlateDetector.h5")

# %%
#plotting the model loss plot and accuracy plot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # 2. Inference Stage

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7564166a-2e43-43e7-9511-476b92194492" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7564166a-2e43-43e7-9511-476b92194492">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving LicensePlate3.jpg to LicensePlate3.jpg
# Saving LicensePlate.jpg to LicensePlate (1).jpg

# %%
import matplotlib.patches as patches
#evaluation on unseen image samples from https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.reddit.com%2Fr%2Fpics%2Fcomments%2F953d61%2Foc_came_across_a_bugatti_chiron_on_my_way_home%2F&psig=AOvVaw3cnpQ9IzKFFipoiIiI3gDk&ust=1614846028336000&source=images&cd=vfe&ved=0CAIQjRxqFwoTCNDuwrbYk-8CFQAAAAAdAAAAABAD

image_list = []
image_list.append('LicensePlate.jpg')
image_list.append('LicensePlate3.jpg')

for orig_image in image_list:
  print(orig_image)
  orig_image = cv2.imread(orig_image)
  image = cv2.resize(orig_image,(224,224),interpolation = cv2.INTER_AREA)
  image = np.reshape(image,(1,224,224,3))
  #np.shape(image))
  out_tensor = model.predict(image)
  #classlabel is by default number plate
  #print(out_tensor[0][0])
  xA,yA,xB,yB= out_tensor[0]
  #visualising
  fig,ax = plt.subplots()
  #fig.suptitle("Predicted Labe, fontsize=10)
  ax.imshow(orig_image)
  rect = patches.Rectangle((xA,yA),xB-xA,yB-yA, linewidth=1, edgecolor='r',facecolor='none')
  ax.add_patch(rect)
# Out:
# LicensePlate.jpg
# LicensePlate3.jpg

# %% [markdown]
# # Observation:
# Clearly since the cars in the dataset are not Indian so it failed to predict the bounding box on bugatti. Let's try on Indian car samples also

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-76359581-05da-428b-b702-40c28f88ce6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76359581-05da-428b-b702-40c28f88ce6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving LicensePlate4.jpg to LicensePlate4.jpg
# Saving LicensePlate2.jpg to LicensePlate2.jpg

# %%
import matplotlib.patches as patches
#evaluation on unseen image samples from https://www.google.com/search?q=indian+car+license+plate&tbm=isch&ved=2ahUKEwjo1-_p2JPvAhWdnUsFHS_JCU4Q2-cCegQIABAA&oq=indian+car+license+plate&gs_lcp=CgNpbWcQAzICCAAyCAgAEAgQBxAeUMCKBFjajQRgopAEaABwAHgAgAHxAYgBzAaSAQUwLjIuMpgBAKABAaoBC2d3cy13aXotaW1nwAEB&sclient=img&ei=REc_YOilOp27rtoPr5Kn8AQ&bih=735&biw=1536#imgrc=-rRNcu9VioHTEM
image_list = []
image_list.append('LicensePlate2.jpg')
image_list.append('LicensePlate4.jpg')

for orig_image in image_list:
  print(orig_image)
  orig_image = cv2.imread(orig_image)
  image = cv2.resize(orig_image,(224,224),interpolation = cv2.INTER_AREA)
  image = np.reshape(image,(1,224,224,3))
  #np.shape(image))
  out_tensor = model.predict(image)
  #classlabel is by default number plate
  #print(out_tensor[0][0])
  xA,yA,xB,yB= out_tensor[0]
  #visualising
  fig,ax = plt.subplots()
  #fig.suptitle("Predicted Labe, fontsize=10)
  ax.imshow(orig_image)
  rect = patches.Rectangle((xA,yA),xB-xA,yB-yA, linewidth=1, edgecolor='r',facecolor='none')
  ax.add_patch(rect)
# Out:
# LicensePlate2.jpg
# LicensePlate4.jpg

# %%
#let's try on val set samples, train_set_samples
image_list = [val_image[0], val_image[5], train_image[1], train_image[63]]
for orig_image in image_list:
  orig_image = array_to_img(orig_image)
  #image = cv2.resize(orig_image,(224,224),interpolation = cv2.INTER_AREA)
  image = np.reshape(orig_image,(1,224,224,3))
  #np.shape(image))
  out_tensor = model.predict(image)
  #classlabel is by default number plate
  #print(out_tensor[0][0])
  xA,yA,xB,yB= out_tensor[0]
  #visualising
  fig,ax = plt.subplots()
  #fig.suptitle("Predicted Labe, fontsize=10)
  ax.imshow(orig_image)
  rect = patches.Rectangle((xA,yA),xB-xA,yB-yA, linewidth=1, edgecolor='r',facecolor='none')
  ax.add_patch(rect)

# %% [markdown]
# # Conclusion till this Point
# Model's accuracy is not at all great in this POC model designed from scratch and obviously due to the fact that we directly tried to regress the bbox coordinates instead of Anchor Boxes !
#
# # Next Steps
# We'll add the Anchor box + NMS functionality to our model and improve its accuracy(Hopefully) in our next trial
