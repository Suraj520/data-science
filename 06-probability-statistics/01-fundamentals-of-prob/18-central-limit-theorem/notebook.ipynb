# %% [markdown]
# #### About
# > Central Limit Theorem
#
# - It is a fundamental concept in statistics that describes the behaviour of the mean of a random sample of independent observations drawn from any distribution, as the sample size becomes sufficiently large.
#
# - It states that regardless of the shape of the original population distribution, The distribution of the sample means approaches a normal distribution, as the sample size increases.
#
# - This is important because it allows us to make inferences about the population mean using a sample mean, and to use statistical tests that assume normality.
#
# - Real world use cases include
# 1. Survey sampling - When conducting a survey, It is usually not pract. to collect data from the entire population. Instead, a sample is drawn from the population and statistics are computed based on the sample. The CLT allows us to make inferences about the population mean based on the sample mean.
#
# 2. Quality control - In manufacturing, It is imp. to ensure that products meet certain quality stds. Samples of the products are tested and the mean of the sample is used to estimate the mean of the population. The CLT helps us to determine how many samples are needed to estimate the population mean with a given level of accuracy.
#
# 3. Finance - It is used to analyze stock returns. By assumption, stock returns are normally distributed, finance analysts can make predictions about future returns and estimate the probability of different outcomes.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the parameters of the distribution
mu = 50
sigma = 10

# Generate 1000 random samples from the distribution
samples = np.random.normal(mu, sigma, 1000)

# %%
# Calculate the sample means for different sample sizes
means = []
for i in range(1, 1001):
    means.append(np.mean(samples[:i]))

# %%
# Plot the distribution of the sample means
plt.hist(means, bins=30, alpha=0.5, color='blue')
plt.xlabel('Sample Means')
plt.ylabel('Frequency')
plt.title('Distribution of Sample Means')
plt.show()

# %% [markdown]
# We can observe that as the sample size increases, the dist of the sample means become more and more normal. This is CLT.
