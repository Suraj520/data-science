# %% [markdown]
# #### About
#
# > Shallow neural networks
#
#
# Shallow neural networks, also known as single-layer neural networks, consist of a single neural layer connected to an input layer and an output layer. The output of the network is obtained by applying an activation function to the weighted sum of the inputs. Mathematically, the output of a shallow neural network can be expressed as:
#
#
# Z = W*X + b
# A = g(Z)
#
# where X is the input vector, W is the weight matrix, b is the bias vector, Z is the weighted sum of the inputs, g() is the activation function, and A is the output of the network.

# %%
# Importing required libraries
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# Creating a shallow neural network
model = Sequential()
model.add(Dense(units=1, input_dim=2, activation='sigmoid'))

# Compiling the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Training the model
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 1, 1, 0])
model.fit(X, y, epochs=100, batch_size=1)

# Predicting new data
new_X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
predictions = model.predict(new_X)
# Out:
# 2023-04-22 00:22:51.415847: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-22 00:22:59.220259: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-22 00:22:59.244018: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-22 00:23:15.805304: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-04-22 00:23:27.242551: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-22 00:23:27.243309: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/100
# 4/4 [==============================] - 1s 10ms/step - loss: 0.7265 - accuracy: 0.5000
# Epoch 2/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7260 - accuracy: 0.5000
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7259 - accuracy: 0.5000
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7259 - accuracy: 0.5000
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7258 - accuracy: 0.5000
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7257 - accuracy: 0.5000
# Epoch 7/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7257 - accuracy: 0.5000
# Epoch 8/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7256 - accuracy: 0.5000
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7257 - accuracy: 0.5000
# Epoch 10/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7256 - accuracy: 0.5000
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7255 - accuracy: 0.5000
# Epoch 12/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7254 - accuracy: 0.5000
# Epoch 13/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7254 - accuracy: 0.5000
# Epoch 14/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7254 - accuracy: 0.5000
# Epoch 15/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7254 - accuracy: 0.5000
# Epoch 16/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7254 - accuracy: 0.5000
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7254 - accuracy: 0.5000
# Epoch 18/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7252 - accuracy: 0.5000
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7252 - accuracy: 0.5000
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7252 - accuracy: 0.5000
# Epoch 21/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7251 - accuracy: 0.5000
# Epoch 22/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7250 - accuracy: 0.5000
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7250 - accuracy: 0.5000
# Epoch 24/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7250 - accuracy: 0.5000
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7249 - accuracy: 0.5000
# Epoch 26/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7249 - accuracy: 0.5000
# Epoch 27/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7248 - accuracy: 0.5000
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7248 - accuracy: 0.5000
# Epoch 29/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7248 - accuracy: 0.5000
# Epoch 30/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7247 - accuracy: 0.5000
# Epoch 31/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7246 - accuracy: 0.5000
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7247 - accuracy: 0.5000
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7246 - accuracy: 0.5000
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7247 - accuracy: 0.5000
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7246 - accuracy: 0.5000
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7244 - accuracy: 0.5000
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7245 - accuracy: 0.5000
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7244 - accuracy: 0.5000
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7243 - accuracy: 0.5000
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7243 - accuracy: 0.5000
# Epoch 41/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7242 - accuracy: 0.5000
# Epoch 42/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7244 - accuracy: 0.5000
# Epoch 43/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7242 - accuracy: 0.5000
# Epoch 44/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7241 - accuracy: 0.5000
# Epoch 45/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7240 - accuracy: 0.5000
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7241 - accuracy: 0.5000
# Epoch 47/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7240 - accuracy: 0.5000
# Epoch 48/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7240 - accuracy: 0.5000
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7239 - accuracy: 0.5000
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7239 - accuracy: 0.5000
# Epoch 51/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7239 - accuracy: 0.5000
# Epoch 52/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7238 - accuracy: 0.5000
# Epoch 53/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7238 - accuracy: 0.5000
# Epoch 54/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7237 - accuracy: 0.5000
# Epoch 55/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7237 - accuracy: 0.5000
# Epoch 56/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7236 - accuracy: 0.5000
# Epoch 57/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7236 - accuracy: 0.5000
# Epoch 58/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7236 - accuracy: 0.5000
# Epoch 59/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7235 - accuracy: 0.5000
# Epoch 60/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7235 - accuracy: 0.5000
# Epoch 61/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7234 - accuracy: 0.5000
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7234 - accuracy: 0.5000
# Epoch 63/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7233 - accuracy: 0.5000
# Epoch 64/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7234 - accuracy: 0.5000
# Epoch 65/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7233 - accuracy: 0.5000
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7232 - accuracy: 0.5000
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7232 - accuracy: 0.5000
# Epoch 68/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7232 - accuracy: 0.5000
# Epoch 69/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7232 - accuracy: 0.5000
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7230 - accuracy: 0.5000
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7231 - accuracy: 0.5000
# Epoch 72/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7230 - accuracy: 0.5000
# Epoch 73/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7230 - accuracy: 0.5000
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7230 - accuracy: 0.5000
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7228 - accuracy: 0.5000
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7229 - accuracy: 0.5000
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7227 - accuracy: 0.5000
# Epoch 78/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7228 - accuracy: 0.5000
# Epoch 79/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7228 - accuracy: 0.5000
# Epoch 80/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7227 - accuracy: 0.5000
# Epoch 81/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7226 - accuracy: 0.5000
# Epoch 82/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7226 - accuracy: 0.5000
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7226 - accuracy: 0.5000
# Epoch 84/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7225 - accuracy: 0.5000
# Epoch 85/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7225 - accuracy: 0.5000
# Epoch 86/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7225 - accuracy: 0.5000
# Epoch 87/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7224 - accuracy: 0.5000
# Epoch 88/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7224 - accuracy: 0.5000
# Epoch 89/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7223 - accuracy: 0.5000
# Epoch 90/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7222 - accuracy: 0.5000
# Epoch 91/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7223 - accuracy: 0.5000
# Epoch 92/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7223 - accuracy: 0.5000
# Epoch 93/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7222 - accuracy: 0.5000
# Epoch 94/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7221 - accuracy: 0.5000
# Epoch 95/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7221 - accuracy: 0.5000
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7222 - accuracy: 0.5000
# Epoch 97/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7220 - accuracy: 0.5000
# Epoch 98/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7219 - accuracy: 0.5000
# Epoch 99/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7220 - accuracy: 0.5000
# Epoch 100/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7219 - accuracy: 0.5000
# 1/1 [==============================] - 0s 344ms/step

# %%
print(predictions)
# Out:
# [[0.5020013 ]
#  [0.32961342]
#  [0.6576205 ]
#  [0.483698  ]]

# %% [markdown]
# In this example, we create a shallow neural network with one layer containing a neuron. The input dimension is 2 because we have two input functions. We use a sigmoid activation function for binary classification and summarize the model with a binary cross-entropy loss function. We then train the model on a small data set and make predictions on new data.
