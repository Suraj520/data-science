# %% [markdown]
# #### About
# Image classification using ViT in PyTorch
# Dataset link - https://www.kaggle.com/datasets/gpiosenka/100-bird-species

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Datasets/')
# !unzip archive.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/WHITE CHEEKED TURACO/080.jpg
#   inflating: train/WHITE CHEEKED TURACO/081.jpg
#   inflating: train/WHITE CHEEKED TURACO/082.jpg
#   inflating: train/WHITE CHEEKED TURACO/083.jpg
#   inflating: train/WHITE CHEEKED TURACO/084.jpg
#   inflating: train/WHITE CHEEKED TURACO/085.jpg
#   inflating: train/WHITE CHEEKED TURACO/086.jpg
#   inflating: train/WHITE CHEEKED TURACO/087.jpg
#   inflating: train/WHITE CHEEKED TURACO/088.jpg
#   inflating: train/WHITE CHEEKED TURACO/089.jpg
#   inflating: train/WHITE CHEEKED TURACO/090.jpg
#   inflating: train/WHITE CHEEKED TURACO/091.jpg
#   inflating: train/WHITE CHEEKED TURACO/092.jpg
#   inflating: train/WHITE CHEEKED TURACO/093.jpg
#   inflating: train/WHITE CHEEKED TURACO/094.jpg
#   inflating: train/WHITE CHEEKED TURACO/095.jpg
#   inflating: train/WHITE CHEEKED TURACO/096.jpg
#   inflating: train/WHITE CHEEKED TURACO/097.jpg
#   inflating: train/WHITE CHEEKED TURACO/098.jpg
#   inflating: train/WHITE CHEEKED TURACO/099.jpg
#   inflating: train/WHITE CHEEKED TURACO/100.jpg
#   inflating: train/WHITE CHEEKED TURACO/101.jpg
#   inflating: train/WHITE CHEEKED TURACO/102.jpg
#   inflating: train/WHITE CHEEKED TURACO/103.jpg
#   inflating: train/WHITE CHEEKED TURACO/104.jpg
#   inflating: train/WHITE CHEEKED TURACO/105.jpg
#   inflating: train/WHITE CHEEKED TURACO/106.jpg
#   inflating: train/WHITE CHEEKED TURACO/107.jpg
#   inflating: train/WHITE CHEEKED TURACO/108.jpg
#   inflating: train/WHITE CHEEKED TURACO/109.jpg
#   inflating: train/WHITE CHEEKED TURACO/110.jpg
#   inflating: train/WHITE CHEEKED TURACO/111.jpg
#   inflating: train/WHITE CHEEKED TURACO/112.jpg
#   inflating: train/WHITE CHEEKED TURACO/113.jpg
#   inflating: train/WHITE CHEEKED TURACO/114.jpg
#   inflating: train/WHITE CHEEKED TURACO/115.jpg
#   inflating: train/WHITE CHEEKED TURACO/116.jpg
#   inflating: train/WHITE CHEEKED TURACO/117.jpg
#   inflating: train/WHITE CHEEKED TURACO/118.jpg
#   inflating: train/WHITE CHEEKED TURACO/119.jpg
#   inflating: train/WHITE CHEEKED TURACO/120.jpg
#   inflating: train/WHITE CHEEKED TURACO/121.jpg
#   inflating: train/WHITE CHEEKED TURACO/122.jpg
#   inflating: train/WHITE CHEEKED TURACO/123.jpg
#   inflating: train/WHITE CHEEKED TURACO/124.jpg
#   inflating: train/WHITE CHEEKED TURACO/125.jpg
#   inflating: train/WHITE CHEEKED TURACO/126.jpg
#   inflating: train/WHITE CHEEKED TURACO/127.jpg
#   inflating: train/WHITE CHEEKED TURACO/128.jpg
#   inflating: train/WHITE CHEEKED TURACO/129.jpg
#   inflating: train/WHITE CHEEKED TURACO/130.jpg
#   inflating: train/WHITE CHEEKED TURACO/131.jpg
#   inflating: train/WHITE CHEEKED TURACO/132.jpg
#   inflating: train/WHITE CHEEKED TURACO/133.jpg
#   inflating: train/WHITE CHEEKED TURACO/134.jpg
#   inflating: train/WHITE CHEEKED TURACO/135.jpg
#   inflating: train/WHITE CHEEKED TURACO/136.jpg
#   inflating: train/WHITE CHEEKED TURACO/137.jpg
#   inflating: train/WHITE CHEEKED TURACO/138.jpg
#   inflating: train/WHITE CHEEKED TURACO/139.jpg
#   inflating: train/WHITE CHEEKED TURACO/140.jpg
#   inflating: train/WHITE CHEEKED TURACO/141.jpg
#   inflating: train/WHITE CHEEKED TURACO/142.jpg
#   inflating: train/WHITE CHEEKED TURACO/143.jpg
#   inflating: train/WHITE CHEEKED TURACO/144.jpg
#   inflating: train/WHITE CHEEKED TURACO/145.jpg
#   inflating: train/WHITE CHEEKED TURACO/146.jpg
#   inflating: train/WHITE CHEEKED TURACO/147.jpg
#   inflating: train/WHITE CHEEKED TURACO/148.jpg
#   inflating: train/WHITE CHEEKED TURACO/149.jpg
#   inflating: train/WHITE CHEEKED TURACO/150.jpg
#   inflating: train/WHITE CHEEKED TURACO/151.jpg
#   inflating: train/WHITE CHEEKED TURACO/152.jpg
#   inflating: train/WHITE CHEEKED TURACO/153.jpg
#   inflating: train/WHITE CRESTED HORNBILL/001.jpg
#   inflating: train/WHITE CRESTED HORNBILL/002.jpg
#   inflating: train/WHITE CRESTED HORNBILL/003.jpg
#   inflating: train/WHITE CRESTED HORNBILL/004.jpg
#   inflating: train/WHITE CRESTED HORNBILL/005.jpg
#   inflating: train/WHITE CRESTED HORNBILL/006.jpg
#   inflating: train/WHITE CRESTED HORNBILL/007.jpg
#   inflating: train/WHITE CRESTED HORNBILL/008.jpg
#   inflating: train/WHITE CRESTED HORNBILL/009.jpg
#   inflating: train/WHITE CRESTED HORNBILL/010.jpg
#   inflating: train/WHITE CRESTED HORNBILL/011.jpg
#   inflating: train/WHITE CRESTED HORNBILL/012.jpg
#   inflating: train/WHITE CRESTED HORNBILL/013.jpg
#   inflating: train/WHITE CRESTED HORNBILL/014.jpg
#   inflating: train/WHITE CRESTED HORNBILL/015.jpg
#   inflating: train/WHITE CRESTED HORNBILL/016.jpg
#   inflating: train/WHITE CRESTED HORNBILL/017.jpg
#   inflating: train/WHITE CRESTED HORNBILL/018.jpg
#   inflating: train/WHITE CRESTED HORNBILL/019.jpg
#   inflating: train/WHITE CRESTED HORNBILL/020.jpg
#   inflating: train/WHITE CRESTED HORNBILL/021.jpg
#   inflating: train/WHITE CRESTED HORNBILL/022.jpg
#   inflating: train/WHITE CRESTED HORNBILL/023.jpg
#   inflating: train/WHITE CRESTED HORNBILL/024.jpg
#   inflating: train/WHITE CRESTED HORNBILL/025.jpg
#   inflating: train/WHITE CRESTED HORNBILL/026.jpg
#   inflating: train/WHITE CRESTED HORNBILL/027.jpg
#   inflating: train/WHITE CRESTED HORNBILL/028.jpg
#   inflating: train/WHITE CRESTED HORNBILL/029.jpg
#   inflating: train/WHITE CRESTED HORNBILL/030.jpg
#   inflating: train/WHITE CRESTED HORNBILL/031.jpg
#   inflating: train/WHITE CRESTED HORNBILL/032.jpg
#   inflating: train/WHITE CRESTED HORNBILL/033.jpg
#   inflating: train/WHITE CRESTED HORNBILL/034.jpg
#   inflating: train/WHITE CRESTED HORNBILL/035.jpg
#   inflating: train/WHITE CRESTED HORNBILL/036.jpg
#   inflating: train/WHITE CRESTED HORNBILL/037.jpg
#   inflating: train/WHITE CRESTED HORNBILL/038.jpg
#   inflating: train/WHITE CRESTED HORNBILL/039.jpg
#   inflating: train/WHITE CRESTED HORNBILL/040.jpg
#   inflating: train/WHITE CRESTED HORNBILL/041.jpg
#   inflating: train/WHITE CRESTED HORNBILL/042.jpg
#   inflating: train/WHITE CRESTED HORNBILL/043.jpg
#   inflating: train/WHITE CRESTED HORNBILL/044.jpg
#   inflating: train/WHITE CRESTED HORNBILL/045.jpg
#   inflating: train/WHITE CRESTED HORNBILL/046.jpg
#   inflating: train/WHITE CRESTED HORNBILL/047.jpg
#   inflating: train/WHITE CRESTED HORNBILL/048.jpg
#   inflating: train/WHITE CRESTED HORNBILL/049.jpg
#   inflating: train/WHITE CRESTED HORNBILL/050.jpg
#   inflating: train/WHITE CRESTED HORNBILL/051.jpg
#   inflating: train/WHITE CRESTED HORNBILL/052.jpg
#   inflating: train/WHITE CRESTED HORNBILL/053.jpg
#   inflating: train/WHITE CRESTED HORNBILL/054.jpg
#   inflating: train/WHITE CRESTED HORNBILL/055.jpg
#   inflating: train/WHITE CRESTED HORNBILL/056.jpg
#   inflating: train/WHITE CRESTED HORNBILL/057.jpg
#   inflating: train/WHITE CRESTED HORNBILL/058.jpg
#   inflating: train/WHITE CRESTED HORNBILL/059.jpg
#   inflating: train/WHITE CRESTED HORNBILL/060.jpg
#   inflating: train/WHITE CRESTED HORNBILL/061.jpg
#   inflating: train/WHITE CRESTED HORNBILL/062.jpg
#   inflating: train/WHITE CRESTED HORNBILL/063.jpg
#   inflating: train/WHITE CRESTED HORNBILL/064.jpg
#   inflating: train/WHITE CRESTED HORNBILL/065.jpg
#   inflating: train/WHITE CRESTED HORNBILL/066.jpg
#   inflating: train/WHITE CRESTED HORNBILL/067.jpg
#   inflating: train/WHITE CRESTED HORNBILL/068.jpg
#   inflating: train/WHITE CRESTED HORNBILL/069.jpg
#   inflating: train/WHITE CRESTED HORNBILL/070.jpg
#   inflating: train/WHITE CRESTED HORNBILL/071.jpg
#   inflating: train/WHITE CRESTED HORNBILL/072.jpg
#   inflating: train/WHITE CRESTED HORNBILL/073.jpg
#   inflating: train/WHITE CRESTED HORNBILL/074.jpg
#   inflating: train/WHITE CRESTED HORNBILL/075.jpg
#   inflating: train/WHITE CRESTED HORNBILL/076.jpg
#   inflating: train/WHITE CRESTED HORNBILL/077.jpg
#   inflating: train/WHITE CRESTED HORNBILL/078.jpg
#   inflating: train/WHITE CRESTED HORNBILL/079.jpg
#   inflating: train/WHITE CRESTED HORNBILL/080.jpg
#   inflating: train/WHITE CRESTED HORNBILL/081.jpg
#   inflating: train/WHITE CRESTED HORNBILL/082.jpg
#   inflating: train/WHITE CRESTED HORNBILL/083.jpg
#   inflating: train/WHITE CRESTED HORNBILL/084.jpg
#   inflating: train/WHITE CRESTED HORNBILL/085.jpg
#   inflating: train/WHITE CRESTED HORNBILL/086.jpg
#   inflating: train/WHITE CRESTED HORNBILL/087.jpg
#   inflating: train/WHITE CRESTED HORNBILL/088.jpg
#   inflating: train/WHITE CRESTED HORNBILL/089.jpg
#   inflating: train/WHITE CRESTED HORNBILL/090.jpg
#   inflating: train/WHITE CRESTED HORNBILL/091.jpg
#   inflating: train/WHITE CRESTED HORNBILL/092.jpg
#   inflating: train/WHITE CRESTED HORNBILL/093.jpg
#   inflating: train/WHITE CRESTED HORNBILL/094.jpg
#   inflating: train/WHITE CRESTED HORNBILL/095.jpg
#   inflating: train/WHITE CRESTED HORNBILL/096.jpg
#   inflating: train/WHITE CRESTED HORNBILL/097.jpg
#   inflating: train/WHITE CRESTED HORNBILL/098.jpg
#   inflating: train/WHITE CRESTED HORNBILL/099.jpg
#   inflating: train/WHITE CRESTED HORNBILL/100.jpg
#   inflating: train/WHITE CRESTED HORNBILL/101.jpg
#   inflating: train/WHITE CRESTED HORNBILL/102.jpg
#   inflating: train/WHITE CRESTED HORNBILL/103.jpg
#   inflating: train/WHITE CRESTED HORNBILL/104.jpg
#   inflating: train/WHITE CRESTED HORNBILL/105.jpg
#   inflating: train/WHITE CRESTED HORNBILL/106.jpg
#   inflating: train/WHITE CRESTED HORNBILL/107.jpg
#   inflating: train/WHITE CRESTED HORNBILL/108.jpg
#   inflating: train/WHITE CRESTED HORNBILL/109.jpg
#   inflating: train/WHITE CRESTED HORNBILL/110.jpg
#   inflating: train/WHITE CRESTED HORNBILL/111.jpg
#   inflating: train/WHITE CRESTED HORNBILL/112.jpg
#   inflating: train/WHITE CRESTED HORNBILL/113.jpg
#   inflating: train/WHITE CRESTED HORNBILL/114.jpg
#   inflating: train/WHITE CRESTED HORNBILL/115.jpg
#   inflating: train/WHITE CRESTED HORNBILL/116.jpg
#   inflating: train/WHITE CRESTED HORNBILL/117.jpg
#   inflating: train/WHITE CRESTED HORNBILL/118.jpg
#   inflating: train/WHITE CRESTED HORNBILL/119.jpg
#   inflating: train/WHITE CRESTED HORNBILL/120.jpg
#   inflating: train/WHITE CRESTED HORNBILL/121.jpg
#   inflating: train/WHITE CRESTED HORNBILL/122.jpg
#   inflating: train/WHITE CRESTED HORNBILL/123.jpg
#   inflating: train/WHITE CRESTED HORNBILL/124.jpg
#   inflating: train/WHITE CRESTED HORNBILL/125.jpg
#   inflating: train/WHITE CRESTED HORNBILL/126.jpg
#   inflating: train/WHITE CRESTED HORNBILL/127.jpg
#   inflating: train/WHITE CRESTED HORNBILL/128.jpg
#   inflating: train/WHITE CRESTED HORNBILL/129.jpg
#   inflating: train/WHITE CRESTED HORNBILL/130.jpg
#   inflating: train/WHITE CRESTED HORNBILL/131.jpg
#   inflating: train/WHITE CRESTED HORNBILL/132.jpg
#   inflating: train/WHITE CRESTED HORNBILL/133.jpg
#   inflating: train/WHITE CRESTED HORNBILL/134.jpg
#   inflating: train/WHITE CRESTED HORNBILL/135.jpg
#   inflating: train/WHITE CRESTED HORNBILL/136.jpg
#   inflating: train/WHITE CRESTED HORNBILL/137.jpg
#   inflating: train/WHITE CRESTED HORNBILL/138.jpg
#   inflating: train/WHITE CRESTED HORNBILL/139.jpg
#   inflating: train/WHITE CRESTED HORNBILL/140.jpg
#   inflating: train/WHITE CRESTED HORNBILL/141.jpg
#   inflating: train/WHITE CRESTED HORNBILL/142.jpg
#   inflating: train/WHITE CRESTED HORNBILL/143.jpg
#   inflating: train/WHITE CRESTED HORNBILL/144.jpg
#   inflating: train/WHITE CRESTED HORNBILL/145.jpg
#   inflating: train/WHITE CRESTED HORNBILL/146.jpg
#   inflating: train/WHITE CRESTED HORNBILL/147.jpg
#   inflating: train/WHITE CRESTED HORNBILL/148.jpg
#   inflating: train/WHITE CRESTED HORNBILL/149.jpg
#   inflating: train/WHITE CRESTED HORNBILL/150.jpg
#   inflating: train/WHITE CRESTED HORNBILL/151.jpg
#   inflating: train/WHITE CRESTED HORNBILL/152.jpg
#   inflating: train/WHITE CRESTED HORNBILL/153.jpg
#   inflating: train/WHITE CRESTED HORNBILL/154.jpg
#   inflating: train/WHITE CRESTED HORNBILL/155.jpg
#   inflating: train/WHITE CRESTED HORNBILL/156.jpg
#   inflating: train/WHITE CRESTED HORNBILL/157.jpg
#   inflating: train/WHITE CRESTED HORNBILL/158.jpg
#   inflating: train/WHITE CRESTED HORNBILL/159.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/001.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/002.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/003.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/004.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/005.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/006.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/007.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/008.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/009.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/010.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/011.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/012.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/013.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/014.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/015.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/016.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/017.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/018.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/019.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/020.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/021.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/022.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/023.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/024.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/025.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/026.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/027.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/028.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/029.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/030.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/031.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/032.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/033.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/034.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/035.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/036.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/037.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/038.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/039.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/040.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/041.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/042.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/043.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/044.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/045.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/046.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/047.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/048.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/049.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/050.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/051.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/052.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/053.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/054.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/055.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/056.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/057.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/058.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/059.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/060.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/061.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/062.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/063.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/064.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/065.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/066.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/067.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/068.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/069.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/070.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/071.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/072.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/073.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/074.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/075.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/076.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/077.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/078.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/079.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/080.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/081.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/082.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/083.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/084.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/085.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/086.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/087.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/088.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/089.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/090.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/091.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/092.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/093.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/094.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/095.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/096.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/097.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/098.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/099.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/100.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/101.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/102.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/103.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/104.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/105.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/106.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/107.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/108.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/109.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/110.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/111.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/112.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/113.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/114.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/115.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/116.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/117.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/118.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/119.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/120.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/121.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/122.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/123.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/124.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/125.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/126.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/127.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/128.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/129.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/130.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/131.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/132.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/133.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/134.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/135.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/136.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/137.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/138.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/139.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/140.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/141.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/142.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/143.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/144.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/145.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/146.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/147.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/148.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/149.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/150.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/151.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/152.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/153.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/154.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/155.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/156.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/157.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/158.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/159.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/160.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/161.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/162.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/163.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/164.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/165.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/166.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/167.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/168.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/169.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/170.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/171.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/172.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/173.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/174.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/175.jpg
#   inflating: train/WHITE EARED HUMMINGBIRD/176.jpg
#   inflating: train/WHITE NECKED RAVEN/001.jpg
#   inflating: train/WHITE NECKED RAVEN/002.jpg
#   inflating: train/WHITE NECKED RAVEN/003.jpg
#   inflating: train/WHITE NECKED RAVEN/004.jpg
#   inflating: train/WHITE NECKED RAVEN/005.jpg
#   inflating: train/WHITE NECKED RAVEN/006.jpg
#   inflating: train/WHITE NECKED RAVEN/007.jpg
#   inflating: train/WHITE NECKED RAVEN/008.jpg
#   inflating: train/WHITE NECKED RAVEN/009.jpg
#   inflating: train/WHITE NECKED RAVEN/010.jpg
#   inflating: train/WHITE NECKED RAVEN/011.jpg
#   inflating: train/WHITE NECKED RAVEN/012.jpg
#   inflating: train/WHITE NECKED RAVEN/013.jpg
#   inflating: train/WHITE NECKED RAVEN/014.jpg
#   inflating: train/WHITE NECKED RAVEN/015.jpg
#   inflating: train/WHITE NECKED RAVEN/016.jpg
#   inflating: train/WHITE NECKED RAVEN/017.jpg
#   inflating: train/WHITE NECKED RAVEN/018.jpg
#   inflating: train/WHITE NECKED RAVEN/019.jpg
#   inflating: train/WHITE NECKED RAVEN/020.jpg
#   inflating: train/WHITE NECKED RAVEN/021.jpg
#   inflating: train/WHITE NECKED RAVEN/022.jpg
#   inflating: train/WHITE NECKED RAVEN/023.jpg
#   inflating: train/WHITE NECKED RAVEN/024.jpg
#   inflating: train/WHITE NECKED RAVEN/025.jpg
#   inflating: train/WHITE NECKED RAVEN/026.jpg
#   inflating: train/WHITE NECKED RAVEN/027.jpg
#   inflating: train/WHITE NECKED RAVEN/028.jpg
#   inflating: train/WHITE NECKED RAVEN/029.jpg
#   inflating: train/WHITE NECKED RAVEN/030.jpg
#   inflating: train/WHITE NECKED RAVEN/031.jpg
#   inflating: train/WHITE NECKED RAVEN/032.jpg
#   inflating: train/WHITE NECKED RAVEN/033.jpg
#   inflating: train/WHITE NECKED RAVEN/034.jpg
#   inflating: train/WHITE NECKED RAVEN/035.jpg
#   inflating: train/WHITE NECKED RAVEN/036.jpg
#   inflating: train/WHITE NECKED RAVEN/037.jpg
#   inflating: train/WHITE NECKED RAVEN/038.jpg
#   inflating: train/WHITE NECKED RAVEN/039.jpg
#   inflating: train/WHITE NECKED RAVEN/040.jpg
#   inflating: train/WHITE NECKED RAVEN/041.jpg
#   inflating: train/WHITE NECKED RAVEN/042.jpg
#   inflating: train/WHITE NECKED RAVEN/043.jpg
#   inflating: train/WHITE NECKED RAVEN/044.jpg
#   inflating: train/WHITE NECKED RAVEN/045.jpg
#   inflating: train/WHITE NECKED RAVEN/046.jpg
#   inflating: train/WHITE NECKED RAVEN/047.jpg
#   inflating: train/WHITE NECKED RAVEN/048.jpg
#   inflating: train/WHITE NECKED RAVEN/049.jpg
#   inflating: train/WHITE NECKED RAVEN/050.jpg
#   inflating: train/WHITE NECKED RAVEN/051.jpg
#   inflating: train/WHITE NECKED RAVEN/052.jpg
#   inflating: train/WHITE NECKED RAVEN/053.jpg
#   inflating: train/WHITE NECKED RAVEN/054.jpg
#   inflating: train/WHITE NECKED RAVEN/055.jpg
#   inflating: train/WHITE NECKED RAVEN/056.jpg
#   inflating: train/WHITE NECKED RAVEN/057.jpg
#   inflating: train/WHITE NECKED RAVEN/058.jpg
#   inflating: train/WHITE NECKED RAVEN/059.jpg
#   inflating: train/WHITE NECKED RAVEN/060.jpg
#   inflating: train/WHITE NECKED RAVEN/061.jpg
#   inflating: train/WHITE NECKED RAVEN/062.jpg
#   inflating: train/WHITE NECKED RAVEN/063.jpg
#   inflating: train/WHITE NECKED RAVEN/064.jpg
#   inflating: train/WHITE NECKED RAVEN/065.jpg
#   inflating: train/WHITE NECKED RAVEN/066.jpg
#   inflating: train/WHITE NECKED RAVEN/067.jpg
#   inflating: train/WHITE NECKED RAVEN/068.jpg
#   inflating: train/WHITE NECKED RAVEN/069.jpg
#   inflating: train/WHITE NECKED RAVEN/070.jpg
#   inflating: train/WHITE NECKED RAVEN/071.jpg
#   inflating: train/WHITE NECKED RAVEN/072.jpg
#   inflating: train/WHITE NECKED RAVEN/073.jpg
#   inflating: train/WHITE NECKED RAVEN/074.jpg
#   inflating: train/WHITE NECKED RAVEN/075.jpg
#   inflating: train/WHITE NECKED RAVEN/076.jpg
#   inflating: train/WHITE NECKED RAVEN/077.jpg
#   inflating: train/WHITE NECKED RAVEN/078.jpg
#   inflating: train/WHITE NECKED RAVEN/079.jpg
#   inflating: train/WHITE NECKED RAVEN/080.jpg
#   inflating: train/WHITE NECKED RAVEN/081.jpg
#   inflating: train/WHITE NECKED RAVEN/082.jpg
#   inflating: train/WHITE NECKED RAVEN/083.jpg
#   inflating: train/WHITE NECKED RAVEN/084.jpg
#   inflating: train/WHITE NECKED RAVEN/085.jpg
#   inflating: train/WHITE NECKED RAVEN/086.jpg
#   inflating: train/WHITE NECKED RAVEN/087.jpg
#   inflating: train/WHITE NECKED RAVEN/088.jpg
#   inflating: train/WHITE NECKED RAVEN/089.jpg
#   inflating: train/WHITE NECKED RAVEN/090.jpg
#   inflating: train/WHITE NECKED RAVEN/091.jpg
#   inflating: train/WHITE NECKED RAVEN/092.jpg
#   inflating: train/WHITE NECKED RAVEN/093.jpg
#   inflating: train/WHITE NECKED RAVEN/094.jpg
#   inflating: train/WHITE NECKED RAVEN/095.jpg
#   inflating: train/WHITE NECKED RAVEN/096.jpg
#   inflating: train/WHITE NECKED RAVEN/097.jpg
#   inflating: train/WHITE NECKED RAVEN/098.jpg
#   inflating: train/WHITE NECKED RAVEN/099.jpg
#   inflating: train/WHITE NECKED RAVEN/100.jpg
#   inflating: train/WHITE NECKED RAVEN/101.jpg
#   inflating: train/WHITE NECKED RAVEN/102.jpg
#   inflating: train/WHITE NECKED RAVEN/103.jpg
#   inflating: train/WHITE NECKED RAVEN/104.jpg
#   inflating: train/WHITE NECKED RAVEN/105.jpg
#   inflating: train/WHITE NECKED RAVEN/106.jpg
#   inflating: train/WHITE NECKED RAVEN/107.jpg
#   inflating: train/WHITE NECKED RAVEN/108.jpg
#   inflating: train/WHITE NECKED RAVEN/109.jpg
#   inflating: train/WHITE NECKED RAVEN/110.jpg
#   inflating: train/WHITE NECKED RAVEN/111.jpg
#   inflating: train/WHITE NECKED RAVEN/112.jpg
#   inflating: train/WHITE NECKED RAVEN/113.jpg
#   inflating: train/WHITE NECKED RAVEN/114.jpg
#   inflating: train/WHITE NECKED RAVEN/115.jpg
#   inflating: train/WHITE NECKED RAVEN/116.jpg
#   inflating: train/WHITE NECKED RAVEN/117.jpg
#   inflating: train/WHITE NECKED RAVEN/118.jpg
#   inflating: train/WHITE NECKED RAVEN/119.jpg
#   inflating: train/WHITE NECKED RAVEN/120.jpg
#   inflating: train/WHITE NECKED RAVEN/121.jpg
#   inflating: train/WHITE NECKED RAVEN/122.jpg
#   inflating: train/WHITE NECKED RAVEN/123.jpg
#   inflating: train/WHITE NECKED RAVEN/124.jpg
#   inflating: train/WHITE NECKED RAVEN/125.jpg
#   inflating: train/WHITE NECKED RAVEN/126.jpg
#   inflating: train/WHITE NECKED RAVEN/127.jpg
#   inflating: train/WHITE NECKED RAVEN/128.jpg
#   inflating: train/WHITE NECKED RAVEN/129.jpg
#   inflating: train/WHITE NECKED RAVEN/130.jpg
#   inflating: train/WHITE NECKED RAVEN/131.jpg
#   inflating: train/WHITE NECKED RAVEN/132.jpg
#   inflating: train/WHITE NECKED RAVEN/133.jpg
#   inflating: train/WHITE NECKED RAVEN/134.jpg
#   inflating: train/WHITE NECKED RAVEN/135.jpg
#   inflating: train/WHITE NECKED RAVEN/136.jpg
#   inflating: train/WHITE NECKED RAVEN/137.jpg
#   inflating: train/WHITE NECKED RAVEN/138.jpg
#   inflating: train/WHITE NECKED RAVEN/139.jpg
#   inflating: train/WHITE NECKED RAVEN/140.jpg
#   inflating: train/WHITE NECKED RAVEN/141.jpg
#   inflating: train/WHITE NECKED RAVEN/142.jpg
#   inflating: train/WHITE NECKED RAVEN/143.jpg
#   inflating: train/WHITE NECKED RAVEN/144.jpg
#   inflating: train/WHITE NECKED RAVEN/145.jpg
#   inflating: train/WHITE NECKED RAVEN/146.jpg
#   inflating: train/WHITE NECKED RAVEN/147.jpg
#   inflating: train/WHITE NECKED RAVEN/148.jpg
#   inflating: train/WHITE NECKED RAVEN/149.jpg
#   inflating: train/WHITE NECKED RAVEN/150.jpg
#   inflating: train/WHITE NECKED RAVEN/151.jpg
#   inflating: train/WHITE NECKED RAVEN/152.jpg
#   inflating: train/WHITE NECKED RAVEN/153.jpg
#   inflating: train/WHITE NECKED RAVEN/154.jpg
#   inflating: train/WHITE NECKED RAVEN/155.jpg
#   inflating: train/WHITE NECKED RAVEN/156.jpg
#   inflating: train/WHITE NECKED RAVEN/157.jpg
#   inflating: train/WHITE NECKED RAVEN/158.jpg
#   inflating: train/WHITE NECKED RAVEN/159.jpg
#   inflating: train/WHITE NECKED RAVEN/160.jpg
#   inflating: train/WHITE NECKED RAVEN/161.jpg
#   inflating: train/WHITE TAILED TROPIC/001.jpg
#   inflating: train/WHITE TAILED TROPIC/002.jpg
#   inflating: train/WHITE TAILED TROPIC/003.jpg
#   inflating: train/WHITE TAILED TROPIC/004.jpg
#   inflating: train/WHITE TAILED TROPIC/005.jpg
#   inflating: train/WHITE TAILED TROPIC/006.jpg
#   inflating: train/WHITE TAILED TROPIC/007.jpg
#   inflating: train/WHITE TAILED TROPIC/008.jpg
#   inflating: train/WHITE TAILED TROPIC/009.jpg
#   inflating: train/WHITE TAILED TROPIC/010.jpg
#   inflating: train/WHITE TAILED TROPIC/011.jpg
#   inflating: train/WHITE TAILED TROPIC/012.jpg
#   inflating: train/WHITE TAILED TROPIC/013.jpg
#   inflating: train/WHITE TAILED TROPIC/014.jpg
#   inflating: train/WHITE TAILED TROPIC/015.jpg
#   inflating: train/WHITE TAILED TROPIC/016.jpg
#   inflating: train/WHITE TAILED TROPIC/017.jpg
#   inflating: train/WHITE TAILED TROPIC/018.jpg
#   inflating: train/WHITE TAILED TROPIC/019.jpg
#   inflating: train/WHITE TAILED TROPIC/020.jpg
#   inflating: train/WHITE TAILED TROPIC/021.jpg
#   inflating: train/WHITE TAILED TROPIC/022.jpg
#   inflating: train/WHITE TAILED TROPIC/023.jpg
#   inflating: train/WHITE TAILED TROPIC/024.jpg
#   inflating: train/WHITE TAILED TROPIC/025.jpg
#   inflating: train/WHITE TAILED TROPIC/026.jpg
#   inflating: train/WHITE TAILED TROPIC/027.jpg
#   inflating: train/WHITE TAILED TROPIC/028.jpg
#   inflating: train/WHITE TAILED TROPIC/029.jpg
#   inflating: train/WHITE TAILED TROPIC/030.jpg
#   inflating: train/WHITE TAILED TROPIC/031.jpg
#   inflating: train/WHITE TAILED TROPIC/032.jpg
#   inflating: train/WHITE TAILED TROPIC/033.jpg
#   inflating: train/WHITE TAILED TROPIC/034.jpg
#   inflating: train/WHITE TAILED TROPIC/035.jpg
#   inflating: train/WHITE TAILED TROPIC/036.jpg
#   inflating: train/WHITE TAILED TROPIC/037.jpg
#   inflating: train/WHITE TAILED TROPIC/038.jpg
#   inflating: train/WHITE TAILED TROPIC/039.jpg
#   inflating: train/WHITE TAILED TROPIC/040.jpg
#   inflating: train/WHITE TAILED TROPIC/041.jpg
#   inflating: train/WHITE TAILED TROPIC/042.jpg
#   inflating: train/WHITE TAILED TROPIC/043.jpg
#   inflating: train/WHITE TAILED TROPIC/044.jpg
#   inflating: train/WHITE TAILED TROPIC/045.jpg
#   inflating: train/WHITE TAILED TROPIC/046.jpg
#   inflating: train/WHITE TAILED TROPIC/047.jpg
#   inflating: train/WHITE TAILED TROPIC/048.jpg
#   inflating: train/WHITE TAILED TROPIC/049.jpg
#   inflating: train/WHITE TAILED TROPIC/050.jpg
#   inflating: train/WHITE TAILED TROPIC/051.jpg
#   inflating: train/WHITE TAILED TROPIC/052.jpg
#   inflating: train/WHITE TAILED TROPIC/053.jpg
#   inflating: train/WHITE TAILED TROPIC/054.jpg
#   inflating: train/WHITE TAILED TROPIC/055.jpg
#   inflating: train/WHITE TAILED TROPIC/056.jpg
#   inflating: train/WHITE TAILED TROPIC/057.jpg
#   inflating: train/WHITE TAILED TROPIC/058.jpg
#   inflating: train/WHITE TAILED TROPIC/059.jpg
#   inflating: train/WHITE TAILED TROPIC/060.jpg
#   inflating: train/WHITE TAILED TROPIC/061.jpg
#   inflating: train/WHITE TAILED TROPIC/062.jpg
#   inflating: train/WHITE TAILED TROPIC/063.jpg
#   inflating: train/WHITE TAILED TROPIC/064.jpg
#   inflating: train/WHITE TAILED TROPIC/065.jpg
#   inflating: train/WHITE TAILED TROPIC/066.jpg
#   inflating: train/WHITE TAILED TROPIC/067.jpg
#   inflating: train/WHITE TAILED TROPIC/068.jpg
#   inflating: train/WHITE TAILED TROPIC/069.jpg
#   inflating: train/WHITE TAILED TROPIC/070.jpg
#   inflating: train/WHITE TAILED TROPIC/071.jpg
#   inflating: train/WHITE TAILED TROPIC/072.jpg
#   inflating: train/WHITE TAILED TROPIC/073.jpg
#   inflating: train/WHITE TAILED TROPIC/074.jpg
#   inflating: train/WHITE TAILED TROPIC/075.jpg
#   inflating: train/WHITE TAILED TROPIC/076.jpg
#   inflating: train/WHITE TAILED TROPIC/077.jpg
#   inflating: train/WHITE TAILED TROPIC/078.jpg
#   inflating: train/WHITE TAILED TROPIC/079.jpg
#   inflating: train/WHITE TAILED TROPIC/080.jpg
#   inflating: train/WHITE TAILED TROPIC/081.jpg
#   inflating: train/WHITE TAILED TROPIC/082.jpg
#   inflating: train/WHITE TAILED TROPIC/083.jpg
#   inflating: train/WHITE TAILED TROPIC/084.jpg
#   inflating: train/WHITE TAILED TROPIC/085.jpg
#   inflating: train/WHITE TAILED TROPIC/086.jpg
#   inflating: train/WHITE TAILED TROPIC/087.jpg
#   inflating: train/WHITE TAILED TROPIC/088.jpg
#   inflating: train/WHITE TAILED TROPIC/089.jpg
#   inflating: train/WHITE TAILED TROPIC/090.jpg
#   inflating: train/WHITE TAILED TROPIC/091.jpg
#   inflating: train/WHITE TAILED TROPIC/092.jpg
#   inflating: train/WHITE TAILED TROPIC/093.jpg
#   inflating: train/WHITE TAILED TROPIC/094.jpg
#   inflating: train/WHITE TAILED TROPIC/095.jpg
#   inflating: train/WHITE TAILED TROPIC/096.jpg
#   inflating: train/WHITE TAILED TROPIC/097.jpg
#   inflating: train/WHITE TAILED TROPIC/098.jpg
#   inflating: train/WHITE TAILED TROPIC/099.jpg
#   inflating: train/WHITE TAILED TROPIC/100.jpg
#   inflating: train/WHITE TAILED TROPIC/101.jpg
#   inflating: train/WHITE TAILED TROPIC/102.jpg
#   inflating: train/WHITE TAILED TROPIC/103.jpg
#   inflating: train/WHITE TAILED TROPIC/104.jpg
#   inflating: train/WHITE TAILED TROPIC/105.jpg
#   inflating: train/WHITE TAILED TROPIC/106.jpg
#   inflating: train/WHITE TAILED TROPIC/107.jpg
#   inflating: train/WHITE TAILED TROPIC/108.jpg
#   inflating: train/WHITE TAILED TROPIC/109.jpg
#   inflating: train/WHITE TAILED TROPIC/110.jpg
#   inflating: train/WHITE TAILED TROPIC/111.jpg
#   inflating: train/WHITE TAILED TROPIC/112.jpg
#   inflating: train/WHITE TAILED TROPIC/113.jpg
#   inflating: train/WHITE TAILED TROPIC/114.jpg
#   inflating: train/WHITE TAILED TROPIC/115.jpg
#   inflating: train/WHITE TAILED TROPIC/116.jpg
#   inflating: train/WHITE TAILED TROPIC/117.jpg
#   inflating: train/WHITE TAILED TROPIC/118.jpg
#   inflating: train/WHITE TAILED TROPIC/119.jpg
#   inflating: train/WHITE TAILED TROPIC/120.jpg
#   inflating: train/WHITE TAILED TROPIC/121.jpg
#   inflating: train/WHITE TAILED TROPIC/122.jpg
#   inflating: train/WHITE TAILED TROPIC/123.jpg
#   inflating: train/WHITE TAILED TROPIC/124.jpg
#   inflating: train/WHITE TAILED TROPIC/125.jpg
#   inflating: train/WHITE TAILED TROPIC/126.jpg
#   inflating: train/WHITE TAILED TROPIC/127.jpg
#   inflating: train/WHITE TAILED TROPIC/128.jpg
#   inflating: train/WHITE TAILED TROPIC/129.jpg
#   inflating: train/WHITE TAILED TROPIC/130.jpg
#   inflating: train/WHITE TAILED TROPIC/131.jpg
#   inflating: train/WHITE TAILED TROPIC/132.jpg
#   inflating: train/WHITE TAILED TROPIC/133.jpg
#   inflating: train/WHITE TAILED TROPIC/134.jpg
#   inflating: train/WHITE TAILED TROPIC/135.jpg
#   inflating: train/WHITE TAILED TROPIC/136.jpg
#   inflating: train/WHITE TAILED TROPIC/137.jpg
#   inflating: train/WHITE TAILED TROPIC/138.jpg
#   inflating: train/WHITE TAILED TROPIC/139.jpg
#   inflating: train/WHITE TAILED TROPIC/140.jpg
#   inflating: train/WHITE TAILED TROPIC/141.jpg
#   inflating: train/WHITE TAILED TROPIC/142.jpg
#   inflating: train/WHITE TAILED TROPIC/143.jpg
#   inflating: train/WHITE TAILED TROPIC/144.jpg
#   inflating: train/WHITE TAILED TROPIC/145.jpg
#   inflating: train/WHITE TAILED TROPIC/146.jpg
#   inflating: train/WHITE TAILED TROPIC/147.jpg
#   inflating: train/WHITE TAILED TROPIC/148.jpg
#   inflating: train/WHITE TAILED TROPIC/149.jpg
#   inflating: train/WHITE TAILED TROPIC/150.jpg
#   inflating: train/WHITE TAILED TROPIC/151.jpg
#   inflating: train/WHITE TAILED TROPIC/152.jpg
#   inflating: train/WHITE TAILED TROPIC/153.jpg
#   inflating: train/WHITE TAILED TROPIC/154.jpg
#   inflating: train/WHITE TAILED TROPIC/155.jpg
#   inflating: train/WHITE TAILED TROPIC/156.jpg
#   inflating: train/WHITE TAILED TROPIC/157.jpg
#   inflating: train/WHITE TAILED TROPIC/158.jpg
#   inflating: train/WHITE TAILED TROPIC/159.jpg
#   inflating: train/WHITE TAILED TROPIC/160.jpg
#   inflating: train/WHITE TAILED TROPIC/161.jpg
#   inflating: train/WHITE TAILED TROPIC/162.jpg
#   inflating: train/WHITE TAILED TROPIC/163.jpg
#   inflating: train/WHITE TAILED TROPIC/164.jpg
#   inflating: train/WHITE TAILED TROPIC/165.jpg
#   inflating: train/WHITE TAILED TROPIC/166.jpg
#   inflating: train/WHITE TAILED TROPIC/167.jpg
#   inflating: train/WHITE TAILED TROPIC/168.jpg
#   inflating: train/WHITE TAILED TROPIC/169.jpg
#   inflating: train/WHITE TAILED TROPIC/170.jpg
#   inflating: train/WHITE TAILED TROPIC/171.jpg
#   inflating: train/WHITE TAILED TROPIC/172.jpg
#   inflating: train/WHITE TAILED TROPIC/173.jpg
#   inflating: train/WHITE TAILED TROPIC/174.jpg
#   inflating: train/WHITE TAILED TROPIC/175.jpg
#   inflating: train/WHITE THROATED BEE EATER/001.jpg
#   inflating: train/WHITE THROATED BEE EATER/002.jpg
#   inflating: train/WHITE THROATED BEE EATER/003.jpg
#   inflating: train/WHITE THROATED BEE EATER/004.jpg
#   inflating: train/WHITE THROATED BEE EATER/005.jpg
#   inflating: train/WHITE THROATED BEE EATER/006.jpg
#   inflating: train/WHITE THROATED BEE EATER/007.jpg
#   inflating: train/WHITE THROATED BEE EATER/008.jpg
#   inflating: train/WHITE THROATED BEE EATER/009.jpg
#   inflating: train/WHITE THROATED BEE EATER/010.jpg
#   inflating: train/WHITE THROATED BEE EATER/011.jpg
#   inflating: train/WHITE THROATED BEE EATER/012.jpg
#   inflating: train/WHITE THROATED BEE EATER/013.jpg
#   inflating: train/WHITE THROATED BEE EATER/014.jpg
#   inflating: train/WHITE THROATED BEE EATER/015.jpg
#   inflating: train/WHITE THROATED BEE EATER/016.jpg
#   inflating: train/WHITE THROATED BEE EATER/017.jpg
#   inflating: train/WHITE THROATED BEE EATER/018.jpg
#   inflating: train/WHITE THROATED BEE EATER/019.jpg
#   inflating: train/WHITE THROATED BEE EATER/020.jpg
#   inflating: train/WHITE THROATED BEE EATER/021.jpg
#   inflating: train/WHITE THROATED BEE EATER/022.jpg
#   inflating: train/WHITE THROATED BEE EATER/023.jpg
#   inflating: train/WHITE THROATED BEE EATER/024.jpg
#   inflating: train/WHITE THROATED BEE EATER/025.jpg
#   inflating: train/WHITE THROATED BEE EATER/026.jpg
#   inflating: train/WHITE THROATED BEE EATER/027.jpg
#   inflating: train/WHITE THROATED BEE EATER/028.jpg
#   inflating: train/WHITE THROATED BEE EATER/029.jpg
#   inflating: train/WHITE THROATED BEE EATER/030.jpg
#   inflating: train/WHITE THROATED BEE EATER/031.jpg
#   inflating: train/WHITE THROATED BEE EATER/032.jpg
#   inflating: train/WHITE THROATED BEE EATER/033.jpg
#   inflating: train/WHITE THROATED BEE EATER/034.jpg
#   inflating: train/WHITE THROATED BEE EATER/035.jpg
#   inflating: train/WHITE THROATED BEE EATER/036.jpg
#   inflating: train/WHITE THROATED BEE EATER/037.jpg
#   inflating: train/WHITE THROATED BEE EATER/038.jpg
#   inflating: train/WHITE THROATED BEE EATER/039.jpg
#   inflating: train/WHITE THROATED BEE EATER/040.jpg
#   inflating: train/WHITE THROATED BEE EATER/041.jpg
#   inflating: train/WHITE THROATED BEE EATER/042.jpg
#   inflating: train/WHITE THROATED BEE EATER/043.jpg
#   inflating: train/WHITE THROATED BEE EATER/044.jpg
#   inflating: train/WHITE THROATED BEE EATER/045.jpg
#   inflating: train/WHITE THROATED BEE EATER/046.jpg
#   inflating: train/WHITE THROATED BEE EATER/047.jpg
#   inflating: train/WHITE THROATED BEE EATER/048.jpg
#   inflating: train/WHITE THROATED BEE EATER/049.jpg
#   inflating: train/WHITE THROATED BEE EATER/050.jpg
#   inflating: train/WHITE THROATED BEE EATER/051.jpg
#   inflating: train/WHITE THROATED BEE EATER/052.jpg
#   inflating: train/WHITE THROATED BEE EATER/053.jpg
#   inflating: train/WHITE THROATED BEE EATER/054.jpg
#   inflating: train/WHITE THROATED BEE EATER/055.jpg
#   inflating: train/WHITE THROATED BEE EATER/056.jpg
#   inflating: train/WHITE THROATED BEE EATER/057.jpg
#   inflating: train/WHITE THROATED BEE EATER/058.jpg
#   inflating: train/WHITE THROATED BEE EATER/059.jpg
#   inflating: train/WHITE THROATED BEE EATER/060.jpg
#   inflating: train/WHITE THROATED BEE EATER/061.jpg
#   inflating: train/WHITE THROATED BEE EATER/062.jpg
#   inflating: train/WHITE THROATED BEE EATER/063.jpg
#   inflating: train/WHITE THROATED BEE EATER/064.jpg
#   inflating: train/WHITE THROATED BEE EATER/065.jpg
#   inflating: train/WHITE THROATED BEE EATER/066.jpg
#   inflating: train/WHITE THROATED BEE EATER/067.jpg
#   inflating: train/WHITE THROATED BEE EATER/068.jpg
#   inflating: train/WHITE THROATED BEE EATER/069.jpg
#   inflating: train/WHITE THROATED BEE EATER/070.jpg
#   inflating: train/WHITE THROATED BEE EATER/071.jpg
#   inflating: train/WHITE THROATED BEE EATER/072.jpg
#   inflating: train/WHITE THROATED BEE EATER/073.jpg
#   inflating: train/WHITE THROATED BEE EATER/074.jpg
#   inflating: train/WHITE THROATED BEE EATER/075.jpg
#   inflating: train/WHITE THROATED BEE EATER/076.jpg
#   inflating: train/WHITE THROATED BEE EATER/077.jpg
#   inflating: train/WHITE THROATED BEE EATER/078.jpg
#   inflating: train/WHITE THROATED BEE EATER/079.jpg
#   inflating: train/WHITE THROATED BEE EATER/080.jpg
#   inflating: train/WHITE THROATED BEE EATER/081.jpg
#   inflating: train/WHITE THROATED BEE EATER/082.jpg
#   inflating: train/WHITE THROATED BEE EATER/083.jpg
#   inflating: train/WHITE THROATED BEE EATER/084.jpg
#   inflating: train/WHITE THROATED BEE EATER/085.jpg
#   inflating: train/WHITE THROATED BEE EATER/086.jpg
#   inflating: train/WHITE THROATED BEE EATER/087.jpg
#   inflating: train/WHITE THROATED BEE EATER/088.jpg
#   inflating: train/WHITE THROATED BEE EATER/089.jpg
#   inflating: train/WHITE THROATED BEE EATER/090.jpg
#   inflating: train/WHITE THROATED BEE EATER/091.jpg
#   inflating: train/WHITE THROATED BEE EATER/092.jpg
#   inflating: train/WHITE THROATED BEE EATER/093.jpg
#   inflating: train/WHITE THROATED BEE EATER/094.jpg
#   inflating: train/WHITE THROATED BEE EATER/095.jpg
#   inflating: train/WHITE THROATED BEE EATER/096.jpg
#   inflating: train/WHITE THROATED BEE EATER/097.jpg
#   inflating: train/WHITE THROATED BEE EATER/098.jpg
#   inflating: train/WHITE THROATED BEE EATER/099.jpg
#   inflating: train/WHITE THROATED BEE EATER/100.jpg
#   inflating: train/WHITE THROATED BEE EATER/101.jpg
#   inflating: train/WHITE THROATED BEE EATER/102.jpg
#   inflating: train/WHITE THROATED BEE EATER/103.jpg
#   inflating: train/WHITE THROATED BEE EATER/104.jpg
#   inflating: train/WHITE THROATED BEE EATER/105.jpg
#   inflating: train/WHITE THROATED BEE EATER/106.jpg
#   inflating: train/WHITE THROATED BEE EATER/107.jpg
#   inflating: train/WHITE THROATED BEE EATER/108.jpg
#   inflating: train/WHITE THROATED BEE EATER/109.jpg
#   inflating: train/WHITE THROATED BEE EATER/110.jpg
#   inflating: train/WHITE THROATED BEE EATER/111.jpg
#   inflating: train/WHITE THROATED BEE EATER/112.jpg
#   inflating: train/WHITE THROATED BEE EATER/113.jpg
#   inflating: train/WHITE THROATED BEE EATER/114.jpg
#   inflating: train/WHITE THROATED BEE EATER/115.jpg
#   inflating: train/WHITE THROATED BEE EATER/116.jpg
#   inflating: train/WHITE THROATED BEE EATER/117.jpg
#   inflating: train/WHITE THROATED BEE EATER/118.jpg
#   inflating: train/WHITE THROATED BEE EATER/119.jpg
#   inflating: train/WHITE THROATED BEE EATER/120.jpg
#   inflating: train/WHITE THROATED BEE EATER/121.jpg
#   inflating: train/WHITE THROATED BEE EATER/122.jpg
#   inflating: train/WHITE THROATED BEE EATER/123.jpg
#   inflating: train/WHITE THROATED BEE EATER/124.jpg
#   inflating: train/WHITE THROATED BEE EATER/125.jpg
#   inflating: train/WHITE THROATED BEE EATER/126.jpg
#   inflating: train/WHITE THROATED BEE EATER/127.jpg
#   inflating: train/WHITE THROATED BEE EATER/128.jpg
#   inflating: train/WHITE THROATED BEE EATER/129.jpg
#   inflating: train/WHITE THROATED BEE EATER/130.jpg
#   inflating: train/WHITE THROATED BEE EATER/131.jpg
#   inflating: train/WHITE THROATED BEE EATER/132.jpg
#   inflating: train/WHITE THROATED BEE EATER/133.jpg
#   inflating: train/WHITE THROATED BEE EATER/134.jpg
#   inflating: train/WHITE THROATED BEE EATER/135.jpg
#   inflating: train/WHITE THROATED BEE EATER/136.jpg
#   inflating: train/WHITE THROATED BEE EATER/137.jpg
#   inflating: train/WHITE THROATED BEE EATER/138.jpg
#   inflating: train/WHITE THROATED BEE EATER/139.jpg
#   inflating: train/WHITE THROATED BEE EATER/140.jpg
#   inflating: train/WHITE THROATED BEE EATER/141.jpg
#   inflating: train/WHITE THROATED BEE EATER/142.jpg
#   inflating: train/WHITE THROATED BEE EATER/143.jpg
#   inflating: train/WHITE THROATED BEE EATER/144.jpg
#   inflating: train/WHITE THROATED BEE EATER/145.jpg
#   inflating: train/WHITE THROATED BEE EATER/146.jpg
#   inflating: train/WHITE THROATED BEE EATER/147.jpg
#   inflating: train/WHITE THROATED BEE EATER/148.jpg
#   inflating: train/WHITE THROATED BEE EATER/149.jpg
#   inflating: train/WHITE THROATED BEE EATER/150.jpg
#   inflating: train/WHITE THROATED BEE EATER/151.jpg
#   inflating: train/WHITE THROATED BEE EATER/152.jpg
#   inflating: train/WHITE THROATED BEE EATER/153.jpg
#   inflating: train/WHITE THROATED BEE EATER/154.jpg
#   inflating: train/WHITE THROATED BEE EATER/155.jpg
#   inflating: train/WHITE THROATED BEE EATER/156.jpg
#   inflating: train/WHITE THROATED BEE EATER/157.jpg
#   inflating: train/WHITE THROATED BEE EATER/158.jpg
#   inflating: train/WHITE THROATED BEE EATER/159.jpg
#   inflating: train/WHITE THROATED BEE EATER/160.jpg
#   inflating: train/WHITE THROATED BEE EATER/161.jpg
#   inflating: train/WHITE THROATED BEE EATER/162.jpg
#   inflating: train/WHITE THROATED BEE EATER/163.jpg
#   inflating: train/WHITE THROATED BEE EATER/164.jpg
#   inflating: train/WILD TURKEY/001.jpg
#   inflating: train/WILD TURKEY/002.jpg
#   inflating: train/WILD TURKEY/003.jpg
#   inflating: train/WILD TURKEY/004.jpg
#   inflating: train/WILD TURKEY/005.jpg
#   inflating: train/WILD TURKEY/006.jpg
#   inflating: train/WILD TURKEY/007.jpg
#   inflating: train/WILD TURKEY/008.jpg
#   inflating: train/WILD TURKEY/009.jpg
#   inflating: train/WILD TURKEY/010.jpg
#   inflating: train/WILD TURKEY/011.jpg
#   inflating: train/WILD TURKEY/012.jpg
#   inflating: train/WILD TURKEY/013.jpg
#   inflating: train/WILD TURKEY/014.jpg
#   inflating: train/WILD TURKEY/015.jpg
#   inflating: train/WILD TURKEY/016.jpg
#   inflating: train/WILD TURKEY/017.jpg
#   inflating: train/WILD TURKEY/018.jpg
#   inflating: train/WILD TURKEY/019.jpg
#   inflating: train/WILD TURKEY/020.jpg
#   inflating: train/WILD TURKEY/021.jpg
#   inflating: train/WILD TURKEY/022.jpg
#   inflating: train/WILD TURKEY/023.jpg
#   inflating: train/WILD TURKEY/024.jpg
#   inflating: train/WILD TURKEY/025.jpg
#   inflating: train/WILD TURKEY/026.jpg
#   inflating: train/WILD TURKEY/027.jpg
#   inflating: train/WILD TURKEY/028.jpg
#   inflating: train/WILD TURKEY/029.jpg
#   inflating: train/WILD TURKEY/030.jpg
#   inflating: train/WILD TURKEY/031.jpg
#   inflating: train/WILD TURKEY/032.jpg
#   inflating: train/WILD TURKEY/033.jpg
#   inflating: train/WILD TURKEY/034.jpg
#   inflating: train/WILD TURKEY/035.jpg
#   inflating: train/WILD TURKEY/036.jpg
# ...
#   inflating: valid/SCARLET FACED LIOCICHLA/3.jpg
#   inflating: valid/SCARLET FACED LIOCICHLA/4.jpg
#   inflating: valid/SCARLET FACED LIOCICHLA/5.jpg
#   inflating: valid/SCARLET IBIS/1.jpg
#   inflating: valid/SCARLET IBIS/2.jpg
#   inflating: valid/SCARLET IBIS/3.jpg
#   inflating: valid/SCARLET IBIS/4.jpg
#   inflating: valid/SCARLET IBIS/5.jpg
#   inflating: valid/SCARLET MACAW/1.jpg
#   inflating: valid/SCARLET MACAW/2.jpg
#   inflating: valid/SCARLET MACAW/3.jpg
#   inflating: valid/SCARLET MACAW/4.jpg
#   inflating: valid/SCARLET MACAW/5.jpg
#   inflating: valid/SCARLET TANAGER/1.jpg
#   inflating: valid/SCARLET TANAGER/2.jpg
#   inflating: valid/SCARLET TANAGER/3.jpg
#   inflating: valid/SCARLET TANAGER/4.jpg
#   inflating: valid/SCARLET TANAGER/5.jpg
#   inflating: valid/SHOEBILL/1.jpg
#   inflating: valid/SHOEBILL/2.jpg
#   inflating: valid/SHOEBILL/3.jpg
#   inflating: valid/SHOEBILL/4.jpg
#   inflating: valid/SHOEBILL/5.jpg
#   inflating: valid/SHORT BILLED DOWITCHER/1.jpg
#   inflating: valid/SHORT BILLED DOWITCHER/2.jpg
#   inflating: valid/SHORT BILLED DOWITCHER/3.jpg
#   inflating: valid/SHORT BILLED DOWITCHER/4.jpg
#   inflating: valid/SHORT BILLED DOWITCHER/5.jpg
#   inflating: valid/SMITHS LONGSPUR/1.jpg
#   inflating: valid/SMITHS LONGSPUR/2.jpg
#   inflating: valid/SMITHS LONGSPUR/3.jpg
#   inflating: valid/SMITHS LONGSPUR/4.jpg
#   inflating: valid/SMITHS LONGSPUR/5.jpg
#   inflating: valid/SNOW GOOSE/1.jpg
#   inflating: valid/SNOW GOOSE/2.jpg
#   inflating: valid/SNOW GOOSE/3.jpg
#   inflating: valid/SNOW GOOSE/4.jpg
#   inflating: valid/SNOW GOOSE/5.jpg
#   inflating: valid/SNOWY EGRET/1.jpg
#   inflating: valid/SNOWY EGRET/2.jpg
#   inflating: valid/SNOWY EGRET/3.jpg
#   inflating: valid/SNOWY EGRET/4.jpg
#   inflating: valid/SNOWY EGRET/5.jpg
#   inflating: valid/SNOWY OWL/1.jpg
#   inflating: valid/SNOWY OWL/2.jpg
#   inflating: valid/SNOWY OWL/3.jpg
#   inflating: valid/SNOWY OWL/4.jpg
#   inflating: valid/SNOWY OWL/5.jpg
#   inflating: valid/SNOWY PLOVER/1.jpg
#   inflating: valid/SNOWY PLOVER/2.jpg
#   inflating: valid/SNOWY PLOVER/3.jpg
#   inflating: valid/SNOWY PLOVER/4.jpg
#   inflating: valid/SNOWY PLOVER/5.jpg
#   inflating: valid/SORA/1.jpg
#   inflating: valid/SORA/2.jpg
#   inflating: valid/SORA/3.jpg
#   inflating: valid/SORA/4.jpg
#   inflating: valid/SORA/5.jpg
#   inflating: valid/SPANGLED COTINGA/1.jpg
#   inflating: valid/SPANGLED COTINGA/2.jpg
#   inflating: valid/SPANGLED COTINGA/3.jpg
#   inflating: valid/SPANGLED COTINGA/4.jpg
#   inflating: valid/SPANGLED COTINGA/5.jpg
#   inflating: valid/SPLENDID WREN/1.jpg
#   inflating: valid/SPLENDID WREN/2.jpg
#   inflating: valid/SPLENDID WREN/3.jpg
#   inflating: valid/SPLENDID WREN/4.jpg
#   inflating: valid/SPLENDID WREN/5.jpg
#   inflating: valid/SPOON BILED SANDPIPER/1.jpg
#   inflating: valid/SPOON BILED SANDPIPER/2.jpg
#   inflating: valid/SPOON BILED SANDPIPER/3.jpg
#   inflating: valid/SPOON BILED SANDPIPER/4.jpg
#   inflating: valid/SPOON BILED SANDPIPER/5.jpg
#   inflating: valid/SPOTTED CATBIRD/1.jpg
#   inflating: valid/SPOTTED CATBIRD/2.jpg
#   inflating: valid/SPOTTED CATBIRD/3.jpg
#   inflating: valid/SPOTTED CATBIRD/4.jpg
#   inflating: valid/SPOTTED CATBIRD/5.jpg
#   inflating: valid/SPOTTED WHISTLING DUCK/1.jpg
#   inflating: valid/SPOTTED WHISTLING DUCK/2.jpg
#   inflating: valid/SPOTTED WHISTLING DUCK/3.jpg
#   inflating: valid/SPOTTED WHISTLING DUCK/4.jpg
#   inflating: valid/SPOTTED WHISTLING DUCK/5.jpg
#   inflating: valid/SRI LANKA BLUE MAGPIE/1.jpg
#   inflating: valid/SRI LANKA BLUE MAGPIE/2.jpg
#   inflating: valid/SRI LANKA BLUE MAGPIE/3.jpg
#   inflating: valid/SRI LANKA BLUE MAGPIE/4.jpg
#   inflating: valid/SRI LANKA BLUE MAGPIE/5.jpg
#   inflating: valid/STEAMER DUCK/1.jpg
#   inflating: valid/STEAMER DUCK/2.jpg
#   inflating: valid/STEAMER DUCK/3.jpg
#   inflating: valid/STEAMER DUCK/4.jpg
#   inflating: valid/STEAMER DUCK/5.jpg
#   inflating: valid/STORK BILLED KINGFISHER/1.jpg
#   inflating: valid/STORK BILLED KINGFISHER/2.jpg
#   inflating: valid/STORK BILLED KINGFISHER/3.jpg
#   inflating: valid/STORK BILLED KINGFISHER/4.jpg
#   inflating: valid/STORK BILLED KINGFISHER/5.jpg
#   inflating: valid/STRIATED CARACARA/1.jpg
#   inflating: valid/STRIATED CARACARA/2.jpg
#   inflating: valid/STRIATED CARACARA/3.jpg
#   inflating: valid/STRIATED CARACARA/4.jpg
#   inflating: valid/STRIATED CARACARA/5.jpg
#   inflating: valid/STRIPED OWL/1.jpg
#   inflating: valid/STRIPED OWL/2.jpg
#   inflating: valid/STRIPED OWL/3.jpg
#   inflating: valid/STRIPED OWL/4.jpg
#   inflating: valid/STRIPED OWL/5.jpg
#   inflating: valid/STRIPPED MANAKIN/1.jpg
#   inflating: valid/STRIPPED MANAKIN/2.jpg
#   inflating: valid/STRIPPED MANAKIN/3.jpg
#   inflating: valid/STRIPPED MANAKIN/4.jpg
#   inflating: valid/STRIPPED MANAKIN/5.jpg
#   inflating: valid/STRIPPED SWALLOW/1.jpg
#   inflating: valid/STRIPPED SWALLOW/2.jpg
#   inflating: valid/STRIPPED SWALLOW/3.jpg
#   inflating: valid/STRIPPED SWALLOW/4.jpg
#   inflating: valid/STRIPPED SWALLOW/5.jpg
#   inflating: valid/SUNBITTERN/1.jpg
#   inflating: valid/SUNBITTERN/2.jpg
#   inflating: valid/SUNBITTERN/3.jpg
#   inflating: valid/SUNBITTERN/4.jpg
#   inflating: valid/SUNBITTERN/5.jpg
#   inflating: valid/SUPERB STARLING/1.jpg
#   inflating: valid/SUPERB STARLING/2.jpg
#   inflating: valid/SUPERB STARLING/3.jpg
#   inflating: valid/SUPERB STARLING/4.jpg
#   inflating: valid/SUPERB STARLING/5.jpg
#   inflating: valid/SURF SCOTER/1.jpg
#   inflating: valid/SURF SCOTER/2.jpg
#   inflating: valid/SURF SCOTER/3.jpg
#   inflating: valid/SURF SCOTER/4.jpg
#   inflating: valid/SURF SCOTER/5.jpg
#   inflating: valid/SWINHOES PHEASANT/1.jpg
#   inflating: valid/SWINHOES PHEASANT/2.jpg
#   inflating: valid/SWINHOES PHEASANT/3.jpg
#   inflating: valid/SWINHOES PHEASANT/4.jpg
#   inflating: valid/SWINHOES PHEASANT/5.jpg
#   inflating: valid/TAILORBIRD/1.jpg
#   inflating: valid/TAILORBIRD/2.jpg
#   inflating: valid/TAILORBIRD/3.jpg
#   inflating: valid/TAILORBIRD/4.jpg
#   inflating: valid/TAILORBIRD/5.jpg
#   inflating: valid/TAIWAN MAGPIE/1.jpg
#   inflating: valid/TAIWAN MAGPIE/2.jpg
#   inflating: valid/TAIWAN MAGPIE/3.jpg
#   inflating: valid/TAIWAN MAGPIE/4.jpg
#   inflating: valid/TAIWAN MAGPIE/5.jpg
#   inflating: valid/TAKAHE/1.jpg
#   inflating: valid/TAKAHE/2.jpg
#   inflating: valid/TAKAHE/3.jpg
#   inflating: valid/TAKAHE/4.jpg
#   inflating: valid/TAKAHE/5.jpg
#   inflating: valid/TASMANIAN HEN/1.jpg
#   inflating: valid/TASMANIAN HEN/2.jpg
#   inflating: valid/TASMANIAN HEN/3.jpg
#   inflating: valid/TASMANIAN HEN/4.jpg
#   inflating: valid/TASMANIAN HEN/5.jpg
#   inflating: valid/TAWNY FROGMOUTH/1.jpg
#   inflating: valid/TAWNY FROGMOUTH/2.jpg
#   inflating: valid/TAWNY FROGMOUTH/3.jpg
#   inflating: valid/TAWNY FROGMOUTH/4.jpg
#   inflating: valid/TAWNY FROGMOUTH/5.jpg
#   inflating: valid/TEAL DUCK/1.jpg
#   inflating: valid/TEAL DUCK/2.jpg
#   inflating: valid/TEAL DUCK/3.jpg
#   inflating: valid/TEAL DUCK/4.jpg
#   inflating: valid/TEAL DUCK/5.jpg
#   inflating: valid/TIT MOUSE/1.jpg
#   inflating: valid/TIT MOUSE/2.jpg
#   inflating: valid/TIT MOUSE/3.jpg
#   inflating: valid/TIT MOUSE/4.jpg
#   inflating: valid/TIT MOUSE/5.jpg
#   inflating: valid/TOUCHAN/1.jpg
#   inflating: valid/TOUCHAN/2.jpg
#   inflating: valid/TOUCHAN/3.jpg
#   inflating: valid/TOUCHAN/4.jpg
#   inflating: valid/TOUCHAN/5.jpg
#   inflating: valid/TOWNSENDS WARBLER/1.jpg
#   inflating: valid/TOWNSENDS WARBLER/2.jpg
#   inflating: valid/TOWNSENDS WARBLER/3.jpg
#   inflating: valid/TOWNSENDS WARBLER/4.jpg
#   inflating: valid/TOWNSENDS WARBLER/5.jpg
#   inflating: valid/TREE SWALLOW/1.jpg
#   inflating: valid/TREE SWALLOW/2.jpg
#   inflating: valid/TREE SWALLOW/3.jpg
#   inflating: valid/TREE SWALLOW/4.jpg
#   inflating: valid/TREE SWALLOW/5.jpg
#   inflating: valid/TRICOLORED BLACKBIRD/1.jpg
#   inflating: valid/TRICOLORED BLACKBIRD/2.jpg
#   inflating: valid/TRICOLORED BLACKBIRD/3.jpg
#   inflating: valid/TRICOLORED BLACKBIRD/4.jpg
#   inflating: valid/TRICOLORED BLACKBIRD/5.jpg
#   inflating: valid/TROPICAL KINGBIRD/1.jpg
#   inflating: valid/TROPICAL KINGBIRD/2.jpg
#   inflating: valid/TROPICAL KINGBIRD/3.jpg
#   inflating: valid/TROPICAL KINGBIRD/4.jpg
#   inflating: valid/TROPICAL KINGBIRD/5.jpg
#   inflating: valid/TRUMPTER SWAN/1.jpg
#   inflating: valid/TRUMPTER SWAN/2.jpg
#   inflating: valid/TRUMPTER SWAN/3.jpg
#   inflating: valid/TRUMPTER SWAN/4.jpg
#   inflating: valid/TRUMPTER SWAN/5.jpg
#   inflating: valid/TURKEY VULTURE/1.jpg
#   inflating: valid/TURKEY VULTURE/2.jpg
#   inflating: valid/TURKEY VULTURE/3.jpg
#   inflating: valid/TURKEY VULTURE/4.jpg
#   inflating: valid/TURKEY VULTURE/5.jpg
#   inflating: valid/TURQUOISE MOTMOT/1.jpg
#   inflating: valid/TURQUOISE MOTMOT/2.jpg
#   inflating: valid/TURQUOISE MOTMOT/3.jpg
#   inflating: valid/TURQUOISE MOTMOT/4.jpg
#   inflating: valid/TURQUOISE MOTMOT/5.jpg
#   inflating: valid/UMBRELLA BIRD/1.jpg
#   inflating: valid/UMBRELLA BIRD/2.jpg
#   inflating: valid/UMBRELLA BIRD/3.jpg
#   inflating: valid/UMBRELLA BIRD/4.jpg
#   inflating: valid/UMBRELLA BIRD/5.jpg
#   inflating: valid/VARIED THRUSH/1.jpg
#   inflating: valid/VARIED THRUSH/2.jpg
#   inflating: valid/VARIED THRUSH/3.jpg
#   inflating: valid/VARIED THRUSH/4.jpg
#   inflating: valid/VARIED THRUSH/5.jpg
#   inflating: valid/VEERY/1.jpg
#   inflating: valid/VEERY/2.jpg
#   inflating: valid/VEERY/3.jpg
#   inflating: valid/VEERY/4.jpg
#   inflating: valid/VEERY/5.jpg
#   inflating: valid/VENEZUELIAN TROUPIAL/1.jpg
#   inflating: valid/VENEZUELIAN TROUPIAL/2.jpg
#   inflating: valid/VENEZUELIAN TROUPIAL/3.jpg
#   inflating: valid/VENEZUELIAN TROUPIAL/4.jpg
#   inflating: valid/VENEZUELIAN TROUPIAL/5.jpg
#   inflating: valid/VERDIN/1.jpg
#   inflating: valid/VERDIN/2.jpg
#   inflating: valid/VERDIN/3.jpg
#   inflating: valid/VERDIN/4.jpg
#   inflating: valid/VERDIN/5.jpg
#   inflating: valid/VERMILION FLYCATHER/1.jpg
#   inflating: valid/VERMILION FLYCATHER/2.jpg
#   inflating: valid/VERMILION FLYCATHER/3.jpg
#   inflating: valid/VERMILION FLYCATHER/4.jpg
#   inflating: valid/VERMILION FLYCATHER/5.jpg
#   inflating: valid/VICTORIA CROWNED PIGEON/1.jpg
#   inflating: valid/VICTORIA CROWNED PIGEON/2.jpg
#   inflating: valid/VICTORIA CROWNED PIGEON/3.jpg
#   inflating: valid/VICTORIA CROWNED PIGEON/4.jpg
#   inflating: valid/VICTORIA CROWNED PIGEON/5.jpg
#   inflating: valid/VIOLET BACKED STARLING/1.jpg
#   inflating: valid/VIOLET BACKED STARLING/2.jpg
#   inflating: valid/VIOLET BACKED STARLING/3.jpg
#   inflating: valid/VIOLET BACKED STARLING/4.jpg
#   inflating: valid/VIOLET BACKED STARLING/5.jpg
#   inflating: valid/VIOLET GREEN SWALLOW/1.jpg
#   inflating: valid/VIOLET GREEN SWALLOW/2.jpg
#   inflating: valid/VIOLET GREEN SWALLOW/3.jpg
#   inflating: valid/VIOLET GREEN SWALLOW/4.jpg
#   inflating: valid/VIOLET GREEN SWALLOW/5.jpg
#   inflating: valid/VIOLET TURACO/1.jpg
#   inflating: valid/VIOLET TURACO/2.jpg
#   inflating: valid/VIOLET TURACO/3.jpg
#   inflating: valid/VIOLET TURACO/4.jpg
#   inflating: valid/VIOLET TURACO/5.jpg
#   inflating: valid/VULTURINE GUINEAFOWL/1.jpg
#   inflating: valid/VULTURINE GUINEAFOWL/2.jpg
#   inflating: valid/VULTURINE GUINEAFOWL/3.jpg
#   inflating: valid/VULTURINE GUINEAFOWL/4.jpg
#   inflating: valid/VULTURINE GUINEAFOWL/5.jpg
#   inflating: valid/WALL CREAPER/1.jpg
#   inflating: valid/WALL CREAPER/2.jpg
#   inflating: valid/WALL CREAPER/3.jpg
#   inflating: valid/WALL CREAPER/4.jpg
#   inflating: valid/WALL CREAPER/5.jpg
#   inflating: valid/WATTLED CURASSOW/1.jpg
#   inflating: valid/WATTLED CURASSOW/2.jpg
#   inflating: valid/WATTLED CURASSOW/3.jpg
#   inflating: valid/WATTLED CURASSOW/4.jpg
#   inflating: valid/WATTLED CURASSOW/5.jpg
#   inflating: valid/WATTLED LAPWING/1.jpg
#   inflating: valid/WATTLED LAPWING/2.jpg
#   inflating: valid/WATTLED LAPWING/3.jpg
#   inflating: valid/WATTLED LAPWING/4.jpg
#   inflating: valid/WATTLED LAPWING/5.jpg
#   inflating: valid/WHIMBREL/1.jpg
#   inflating: valid/WHIMBREL/2.jpg
#   inflating: valid/WHIMBREL/3.jpg
#   inflating: valid/WHIMBREL/4.jpg
#   inflating: valid/WHIMBREL/5.jpg
#   inflating: valid/WHITE BROWED CRAKE/1.jpg
#   inflating: valid/WHITE BROWED CRAKE/2.jpg
#   inflating: valid/WHITE BROWED CRAKE/3.jpg
#   inflating: valid/WHITE BROWED CRAKE/4.jpg
#   inflating: valid/WHITE BROWED CRAKE/5.jpg
#   inflating: valid/WHITE CHEEKED TURACO/1.jpg
#   inflating: valid/WHITE CHEEKED TURACO/2.jpg
#   inflating: valid/WHITE CHEEKED TURACO/3.jpg
#   inflating: valid/WHITE CHEEKED TURACO/4.jpg
#   inflating: valid/WHITE CHEEKED TURACO/5.jpg
#   inflating: valid/WHITE CRESTED HORNBILL/1.jpg
#   inflating: valid/WHITE CRESTED HORNBILL/2.jpg
#   inflating: valid/WHITE CRESTED HORNBILL/3.jpg
#   inflating: valid/WHITE CRESTED HORNBILL/4.jpg
#   inflating: valid/WHITE CRESTED HORNBILL/5.jpg
#   inflating: valid/WHITE EARED HUMMINGBIRD/1.jpg
#   inflating: valid/WHITE EARED HUMMINGBIRD/2.jpg
#   inflating: valid/WHITE EARED HUMMINGBIRD/3.jpg
#   inflating: valid/WHITE EARED HUMMINGBIRD/4.jpg
#   inflating: valid/WHITE EARED HUMMINGBIRD/5.jpg
#   inflating: valid/WHITE NECKED RAVEN/1.jpg
#   inflating: valid/WHITE NECKED RAVEN/2.jpg
#   inflating: valid/WHITE NECKED RAVEN/3.jpg
#   inflating: valid/WHITE NECKED RAVEN/4.jpg
#   inflating: valid/WHITE NECKED RAVEN/5.jpg
#   inflating: valid/WHITE TAILED TROPIC/1.jpg
#   inflating: valid/WHITE TAILED TROPIC/2.jpg
#   inflating: valid/WHITE TAILED TROPIC/3.jpg
#   inflating: valid/WHITE TAILED TROPIC/4.jpg
#   inflating: valid/WHITE TAILED TROPIC/5.jpg
#   inflating: valid/WHITE THROATED BEE EATER/1.jpg
#   inflating: valid/WHITE THROATED BEE EATER/2.jpg
#   inflating: valid/WHITE THROATED BEE EATER/3.jpg
#   inflating: valid/WHITE THROATED BEE EATER/4.jpg
#   inflating: valid/WHITE THROATED BEE EATER/5.jpg
#   inflating: valid/WILD TURKEY/1.jpg
#   inflating: valid/WILD TURKEY/2.jpg
#   inflating: valid/WILD TURKEY/3.jpg
#   inflating: valid/WILD TURKEY/4.jpg
#   inflating: valid/WILD TURKEY/5.jpg
#   inflating: valid/WILLOW PTARMIGAN/1.jpg
#   inflating: valid/WILLOW PTARMIGAN/2.jpg
#   inflating: valid/WILLOW PTARMIGAN/3.jpg
#   inflating: valid/WILLOW PTARMIGAN/4.jpg
#   inflating: valid/WILLOW PTARMIGAN/5.jpg
#   inflating: valid/WILSONS BIRD OF PARADISE/1.jpg
#   inflating: valid/WILSONS BIRD OF PARADISE/2.jpg
#   inflating: valid/WILSONS BIRD OF PARADISE/3.jpg
#   inflating: valid/WILSONS BIRD OF PARADISE/4.jpg
#   inflating: valid/WILSONS BIRD OF PARADISE/5.jpg
#   inflating: valid/WOOD DUCK/1.jpg
#   inflating: valid/WOOD DUCK/2.jpg
#   inflating: valid/WOOD DUCK/3.jpg
#   inflating: valid/WOOD DUCK/4.jpg
#   inflating: valid/WOOD DUCK/5.jpg
#   inflating: valid/WOOD THRUSH/1.jpg
#   inflating: valid/WOOD THRUSH/2.jpg
#   inflating: valid/WOOD THRUSH/3.jpg
#   inflating: valid/WOOD THRUSH/4.jpg
#   inflating: valid/WOOD THRUSH/5.jpg
#   inflating: valid/WRENTIT/1.jpg
#   inflating: valid/WRENTIT/2.jpg
#   inflating: valid/WRENTIT/3.jpg
#   inflating: valid/WRENTIT/4.jpg
#   inflating: valid/WRENTIT/5.jpg
#   inflating: valid/YELLOW BELLIED FLOWERPECKER/1.jpg
#   inflating: valid/YELLOW BELLIED FLOWERPECKER/2.jpg
#   inflating: valid/YELLOW BELLIED FLOWERPECKER/3.jpg
#   inflating: valid/YELLOW BELLIED FLOWERPECKER/4.jpg
#   inflating: valid/YELLOW BELLIED FLOWERPECKER/5.jpg
#   inflating: valid/YELLOW CACIQUE/1.jpg
#   inflating: valid/YELLOW CACIQUE/2.jpg
#   inflating: valid/YELLOW CACIQUE/3.jpg
#   inflating: valid/YELLOW CACIQUE/4.jpg
#   inflating: valid/YELLOW CACIQUE/5.jpg
#   inflating: valid/YELLOW HEADED BLACKBIRD/1.jpg
#   inflating: valid/YELLOW HEADED BLACKBIRD/2.jpg
#   inflating: valid/YELLOW HEADED BLACKBIRD/3.jpg
#   inflating: valid/YELLOW HEADED BLACKBIRD/4.jpg
#   inflating: valid/YELLOW HEADED BLACKBIRD/5.jpg

# %%
#importing modules
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torchvision
from torchvision import transforms
# !pip install torchinfo --quiet
from torchinfo import summary
from PIL import Image, ImageEnhance
import numpy as np
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#dataset path
train_dir = "/content/drive/MyDrive/Datasets/train/"
val_dir= "/content/drive/MyDrive/Datasets/valid/"

# %%
#image enhancement function while training
enhancers = {
    0: lambda image, f: ImageEnhance.Color(image).enhance(f),
    1: lambda image, f: ImageEnhance.Contrast(image).enhance(f),
    2: lambda image, f: ImageEnhance.Brightness(image).enhance(f),
    3: lambda image, f: ImageEnhance.Sharpness(image).enhance(f)
}

factors = {
        0: lambda: np.random.normal(1.0, 0.3),
        1: lambda: np.random.normal(1.0, 0.1),
        2: lambda: np.random.normal(1.0, 0.1),
        3: lambda: np.random.normal(1.0, 0.3),
    }
    

def enhance(image):
    order = [0, 1, 2, 3]
    np.random.shuffle(order)
    for i in order:
        f = factors[i]()
        image = enhancers[i](image, f)
    return image

# %%
train_transform = transforms.Compose([
    transforms.Resize((224,224),Image.LANCZOS),
    
    transforms.RandomHorizontalFlip(),
    transforms.Lambda(enhance),
    transforms.ToTensor(),
])

val_transform = transforms.Compose([
    transforms.Resize((224,224),Image.LANCZOS),
    transforms.ToTensor()
])

train_data = ImageFolder(train_dir, transform=train_transform)
val_data = ImageFolder(val_dir,transform=val_transform)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/transforms/transforms.py:329: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(

# %%
train_data.__getitem__(5)
# Out:
# (tensor([[[0.7176, 0.7255, 0.7294,  ..., 0.5804, 0.5569, 0.5373],
#           [0.7137, 0.7176, 0.7255,  ..., 0.5882, 0.5647, 0.5608],
#           [0.7059, 0.7137, 0.7176,  ..., 0.5961, 0.5882, 0.5725],
#           ...,
#           [0.3804, 0.3765, 0.3686,  ..., 0.3725, 0.3961, 0.3922],
#           [0.4314, 0.4314, 0.3843,  ..., 0.3647, 0.3804, 0.3843],
#           [0.4000, 0.3961, 0.3843,  ..., 0.3804, 0.3843, 0.3686]],
#
#          [[0.7294, 0.7333, 0.7412,  ..., 0.6353, 0.6196, 0.6000],
#           [0.7255, 0.7294, 0.7333,  ..., 0.6353, 0.6235, 0.6118],
#           [0.7176, 0.7255, 0.7294,  ..., 0.6549, 0.6392, 0.6392],
#           ...,
#           [0.3843, 0.3804, 0.3686,  ..., 0.4392, 0.4667, 0.4588],
#           [0.4314, 0.4314, 0.3843,  ..., 0.4353, 0.4431, 0.4471],
#           [0.4039, 0.4000, 0.3843,  ..., 0.4471, 0.4510, 0.4392]],
#
#          [[0.6235, 0.6314, 0.6353,  ..., 0.3961, 0.3804, 0.3490],
#           [0.6196, 0.6235, 0.6314,  ..., 0.4000, 0.3804, 0.3569],
#           [0.6118, 0.6196, 0.6235,  ..., 0.4000, 0.3725, 0.3647],
#           ...,
#           [0.3608, 0.3569, 0.3490,  ..., 0.2118, 0.2353, 0.2275],
#           [0.4196, 0.4235, 0.3765,  ..., 0.2039, 0.2196, 0.2196],
#           [0.4000, 0.4000, 0.3843,  ..., 0.2196, 0.2196, 0.2078]]]), 0)

# %%
#creating dataloader
batch_size =64
train_loader = DataLoader(train_data,batch_size,shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_data, batch_size,shuffle=True,  num_workers=4, pin_memory=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
for i, (inputs, labels) in enumerate(train_loader):
    print(inputs.shape,labels.shape)
    break
# Out:
# torch.Size([64, 3, 224, 224]) torch.Size([64])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
num_classes = len(train_data.classes)
print(num_classes)
# Out:
# 500

# %%
#Creating a class for extracting embeddings via Patches of images
class ImagePatcher(nn.Module):
    def __init__(self,input_channels=3, patch_size=16, embed_dim=768):
        super().__init__()
        self.patch_size = patch_size
        # creating the embedding layers
        self.img_cropper_layer = nn.Conv2d(in_channels=input_channels, out_channels=embed_dim, kernel_size=patch_size, stride=patch_size, padding=0)
        self.linear_layer = nn.Flatten(start_dim=2, end_dim=3)

    def forward(self,x):
        image_res = x.shape[-1]
        assert image_res% self.patch_size==0 #divisible  by 16

        cropped_img_features = self.img_cropper_layer(x)
        flattened_img_features = self.linear_layer(cropped_img_features)
        flattened_img_features = flattened_img_features.permute(0,2,1)# as per pytorch

        return flattened_img_features

# %%
#defining transformer encoder layer and stacking 12 encoder layers
encoder_layer = nn.TransformerEncoderLayer(d_model=768,nhead=12, dim_feedforward=2048, dropout=0.1, activation='gelu', batch_first=True, norm_first=True)
encoder = nn.TransformerEncoder(encoder_layer=encoder_layer,num_layers=12)

# %%
#defining ViT class
class ViT(nn.Module):
    def __init__(self, img_size=224, num_channel=3, patch_size=16, embed_dim=768, p=0.1, num_layers=12,num_heads=12, hidden_dim=2048,num_classes=500):
        super().__init__()
        assert img_size%patch_size==0
        #embedding
        self.cropping_layer = ImagePatcher(input_channels=num_channel,patch_size=patch_size, embed_dim=embed_dim)

        # class token - *
        self.classtoken = nn.Parameter(torch.randn(1,1,embed_dim), requires_grad=True)

        #positional embedding for each
        num_patches = (img_size*img_size) //patch_size**2

        self.positional_embedding = nn.Parameter(torch.randn(1,num_patches+1, embed_dim))

        #dropout
        self.dropout = nn.Dropout(p=0.1) 

        #encoder 
        self.encoders = nn.TransformerEncoder(encoder_layer= nn.TransformerEncoderLayer(d_model=768,nhead=12, dim_feedforward=2048, dropout=0.1, activation='gelu', batch_first=True, norm_first=True), num_layers=num_layers)

        #mlp
        self.mlp = nn.Sequential(nn.LayerNorm(normalized_shape=embed_dim),
                                 nn.Linear(in_features=embed_dim,out_features=num_classes))
        
    
    def forward(self,x):
        batch_size = x.shape[0]
        x = self.cropping_layer(x)
        cls_token = self.classtoken.expand(batch_size,-1,-1)
        x = torch.cat((cls_token,x), dim=1)
        x = self.positional_embedding + x #similar to NLP [CLS] [0][f1] [1][f2]
        x = self.dropout(x)
        x = self.encoders(x)
        x = self.mlp(x[:,0])

        return x

# %%
model = ViT(num_classes=len(train_data.classes)).to(device)
model
# Out:
# ViT(
#   (cropping_layer): ImagePatcher(
#     (img_cropper_layer): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#     (linear_layer): Flatten(start_dim=2, end_dim=3)
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (encoders): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (4): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (5): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (6): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (7): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (8): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (9): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (10): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (11): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (linear1): Linear(in_features=768, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=768, bias=True)
#         (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (mlp): Sequential(
#     (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=768, out_features=500, bias=True)
#   )
# )

# %%
summary(model,input_size=(1,3,224,224))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ViT                                           [1, 500]                  152,064
# ├─ImagePatcher: 1-1                           [1, 196, 768]             --
# │    └─Conv2d: 2-1                            [1, 768, 14, 14]          590,592
# │    └─Flatten: 2-2                           [1, 768, 196]             --
# ├─Dropout: 1-2                                [1, 197, 768]             --
# ├─TransformerEncoder: 1-3                     [1, 197, 768]             --
# │    └─ModuleList: 2-3                        --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-2      [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-3      [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-4      [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-5      [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-6      [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-7      [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-8      [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-9      [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-10     [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-11     [1, 197, 768]             5,513,984
# │    │    └─TransformerEncoderLayer: 3-12     [1, 197, 768]             5,513,984
# ├─Sequential: 1-4                             [1, 500]                  --
# │    └─LayerNorm: 2-4                         [1, 768]                  1,536
# │    └─Linear: 2-5                            [1, 500]                  384,500
# ===============================================================================================
# Total params: 67,296,500
# Trainable params: 67,296,500
# Non-trainable params: 0
# Total mult-adds (M): 116.14
# ===============================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 1.21
# Params size (MB): 3.91
# Estimated Total Size (MB): 5.72
# ===============================================================================================

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
criterion = torch.nn.CrossEntropyLoss()

# %%
def fit(model, loss_criterion, optimizer, epochs=25):

    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(train_loader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(val_loader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/len(train_data) 
        avg_train_acc = train_acc/len(train_data) 

        # Find average training loss and training accuracy
        avg_valid_loss = valid_loss/len(val_data)  
        avg_valid_acc = valid_acc/len(val_data) 

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])
                
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch+1, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start))
        
            
    return model, history

# %%
model,history = fit(model, criterion,optimizer,10)
# Out:
# Epoch: 1/10

# %%
torch.save(model.state_dict(), 'ViT.pth')

# %%
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Training Loss', 'Val Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.show()

# %%
plt.plot(history[:,2:4])
plt.legend(['Training Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0,1)
plt.show()

# %%
idx_to_class = {v: k for k, v in train_data.class_to_idx.items()}
print(idx_to_class)


def predict(model, test_image_name):
    
    test_image = Image.open(test_image_name).convert('RGB')
    print(np.shape(test_image))
    plt.imshow(test_image)
 
    transform = transforms.Compose([transforms.Resize((224,224)),transforms.ToTensor() 
          ])
    img_normalized = transform(test_image).float()

    if torch.cuda.is_available():
        test_image_tensor = img_normalized.view(1, 3, 224, 224).cuda()
    else:
        test_image_tensor = img_normalized.view(1, 3, 224, 224)
    
    with torch.no_grad():
        model.eval()
        # Model outputs log probabilities
        out = model(test_image_tensor)
        prob = torch.exp(out)
        prob_, class_ = prob.topk(3, dim=1)
        class_ = class_.cpu().numpy()
        for i in range(3):
            print("Predcition", i+1, ":", idx_to_class[class_[0][i]], ", Score: ", prob_.cpu().numpy()[0][i])
