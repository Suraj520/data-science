# %% [markdown]
# # MobileNet V1 SSD network for Object Detection.
#
# ### Implementation from scratch without using TFOD API
#
# Dataset Link : https://www.kaggle.com/mbkinaci/fruit-images-for-object-detection

# %% [markdown]
# ### 1. Training Phase

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/Dataset")
# !unzip fruits_dataset.zip
# Out:
# Archive:  fruits_dataset.zip
# replace test_zip/test/apple_77.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# !ls
# Out:
# checkpoint  fruits_dataset.zip	Indian_Number_plates.json  test_zip  train_zip

# %%
#neccessary module imports
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, ZeroPadding2D,DepthwiseConv2D, ReLU, Input,AveragePooling2D, GlobalAveragePooling2D,Dense,Dropout
from tensorflow.keras.activations import sigmoid,relu
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.models import Sequential,Model
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import xml.etree.ElementTree as ET
import glob
import numpy as np
np.random.seed(42)
import cv2

# %%
#helper functions for parsing the xml content and getting annotation content
def FindNumberBoundingBoxes(root):
    index = 0
    while True:
        if GetInt('xmin', root, index) == -1:
              break
        index += 1
    return index

def GetInt(name, root, index=0):
      return int(GetItem(name, root, index))

def GetItem(name, root, index=0):
    count = 0
    for item in root.iter(name):
        if count == index:
            return item.text
        count += 1
       # Failed to find "index" occurrence of item.
    return -1

def process_xml(xmlfile):
    tree = ET.parse(xmlfile)
    root = tree.getroot()

    num_boxes = FindNumberBoundingBoxes(root)
    attributes = []

    for index in range(num_boxes):
        # Grab the 'index' annotation.
        xmin = GetInt('xmin', root, index)
        ymin = GetInt('ymin', root, index)
        xmax = GetInt('xmax', root, index)
        ymax = GetInt('ymax', root, index)

        width = GetInt('width', root)
        height = GetInt('height', root)
        filename = GetItem('filename', root) + '.JPEG'
        label = GetItem('name', root)
        
    attributes.append([[xmin,ymin,xmax,ymax],[width],[height],[filename],[label]])
    return attributes

# %%
train_path = "/content/drive/MyDrive/Colab Notebooks/Dataset/train_zip/train"
val_path = "/content/drive/MyDrive/Colab Notebooks/Dataset/test_zip/test"

# %%
#visualizing the dataset and validating the Ground truth ROI

#showing first ten samples along with bounding box in the dataset
# Training samples visualisation
idx =0
for train_file, train_annotation in zip(glob.glob(train_path+"/*.jpg"),glob.glob(train_path+"/*.xml")):
    #displaying only first 10 images
    if idx<10:
        # Training image processing
        #reading image 
        train_image = Image.open(train_file)
        #reading bounding box xml file and processing to fetch xA,yA,xB,yB
        train_content = process_xml(train_annotation)
        #checking if filename equals the train_image file name
        if(train_annotation.split('\\')[-1].split('.')[0])==(train_file.split('\\')[-1].split('.')[0]):
            xA,yA,xB,yB = train_content[0][0]
            #processing done
            fig,ax = plt.subplots()
            fig.suptitle("Training image sample #{}/10".format(idx), fontsize=10)
            ax.imshow(train_image)
            rect = patches.Rectangle((xA,yA),xB-xA,yB-yA, linewidth=1, edgecolor='r',facecolor='none')
            ax.add_patch(rect)
        idx+=1

        
# Validation samples visualisation
idx1 =0
for val_file, val_annotation in zip(glob.glob(val_path+"/*.jpg"),glob.glob(val_path+"/*.xml")):
    #displaying only first 10 images
    if idx1<10:
        # Training image processing
        #reading image 
        val_image = Image.open(val_file)
        #reading bounding box xml file and processing to fetch xA,yA,xB,yB
        val_content = process_xml(val_annotation)
        #checking if filename equals the train_image file name
        if(val_annotation.split('\\')[-1].split('.')[0])==(val_file.split('\\')[-1].split('.')[0]):
            xA,yA,xB,yB = val_content[0][0]
            #processing done
            fig,ax = plt.subplots()
            fig.suptitle("validation image sample #{}/10".format(idx1), fontsize=10)
            ax.imshow(val_image)
            rect = patches.Rectangle((xA,yA),xB-xA,yB-yA, linewidth=1, edgecolor='r',facecolor='none')
            ax.add_patch(rect)
        idx1+=1
#checking if number of images == number of annotations or not
print(len(glob.glob(train_path+"/*.jpg"))== len(glob.glob(train_path+"/*.xml")))
print(len(glob.glob(val_path+"/*.jpg"))== len(glob.glob(val_path+"/*.xml")))
# Out:
# True
# True

# %%
#now creating 4 lists to store features and labels
LabelDict = {"apple":0,"banana":1, "orange":2}
train_features, train_coordinates, train_labels, val_features,val_coordinates, val_labels = [],[],[],[],[],[]
#creating list of train,val images and xml files
train_images = glob.glob(train_path+"/*.jpg")
val_images = glob.glob(val_path+"/*.jpg")
train_annotations = glob.glob(train_path+"/*.xml")
val_annotations = glob.glob(val_path+"/*.xml")

#helper function for preprocessing
def normalize_annotation(coordinates, original, resized=(150,150)):
    W,H = np.shape(original)[0], np.shape(original)[1]
    #print(coordinates)
    scale_W,scale_H = 224.0/float(W),224.0/float(H)
    coordinates[0],coordinates[2] = coordinates[0]*scale_W,coordinates[2]*scale_W
    coordinates[1],coordinates[3] = coordinates[1]*scale_H,coordinates[3]*scale_H
    #print(coordinates)
    return coordinates
    
    

#processing train dataset
for idx1 in range(1,len(train_images)):
    for idx2 in range(1,len(train_annotations)):
        if train_images[idx1].split('\\')[-1].split('.')[0] == train_annotations[idx2].split('\\')[-1].split('.')[0] :
            #open image
            train_image_content = cv2.imread(train_images[idx1])
            #reshaping the image
            resized_image_content = cv2.resize(train_image_content,(224,224), interpolation = cv2.INTER_AREA)
            #fetching the label and bounding box
            label = process_xml(train_annotations[idx2])[0][-1][0]
            bounding_box = process_xml(train_annotations[idx2])[0][0]
            #normalising labels as per new size
            #original shape of image
            normalised_coordinates = normalize_annotation(bounding_box,train_image_content)
            #now appending the data to corresponding lists
            print("Processed {} out {} images".format(idx1,len(train_images)))
            train_features.append(np.asarray(resized_image_content))
            train_coordinates.append(normalised_coordinates)
            train_labels.append([LabelDict[label]])
            

#processing val dataset
for idx1 in range(1,len(val_images)):
    for idx2 in range(1,len(val_annotations)):
        if val_images[idx1].split('\\')[-1].split('.')[0] == val_annotations[idx2].split('\\')[-1].split('.')[0] :
            #open image
            val_image_content = cv2.imread(val_images[idx1])
            #reshaping the image
            resized_image_content = cv2.resize(val_image_content,(224,224) ,interpolation = cv2.INTER_AREA)
            #fetching the label and bounding box
            label = process_xml(val_annotations[idx2])[0][-1][0]
            bounding_box = process_xml(val_annotations[idx2])[0][0]
            #normalising labels as per new size
            #original shape of image
            normalised_coordinates = normalize_annotation(bounding_box,val_image_content)
            #now appending the data to corresponding lists
            print("Processed {} out {} images".format(idx1,len(val_images)))
            val_features.append(np.asarray(resized_image_content))
            val_coordinates.append(normalised_coordinates)
            val_labels.append([LabelDict[label]])

    
# #converting each list to numpy array
train_features = np.asarray(train_features)
train_coordinates = np.asarray(train_coordinates)
#converting to one hot encoded
train_labels = tf.keras.utils.to_categorical(
    train_labels, num_classes=3, dtype='float32'
)
val_features = np.asarray(val_features)
val_coordinates = np.asarray(val_coordinates)
#converting to one hot_encoded
val_labels = tf.keras.utils.to_categorical(
    val_labels, num_classes=3, dtype='float32'
)
#printing the final shapes of dataset
print("Shape of training features", np.shape(train_features))
print("Shape of training coordinates",np.shape(train_coordinates))
print("shape of training labels", np.shape(train_labels))

print("Shape of validation features", np.shape(val_features))
print("Shape of validation coordinates",np.shape(val_coordinates))
print("shape of validation labels", np.shape(val_labels))
# Out:
# Processed 1 out 240 images
# Processed 2 out 240 images
# Processed 3 out 240 images
# Processed 4 out 240 images
# Processed 5 out 240 images
# Processed 6 out 240 images
# Processed 7 out 240 images
# Processed 8 out 240 images
# Processed 9 out 240 images
# Processed 10 out 240 images
# Processed 11 out 240 images
# Processed 12 out 240 images
# Processed 13 out 240 images
# Processed 14 out 240 images
# Processed 15 out 240 images
# Processed 16 out 240 images
# Processed 17 out 240 images
# Processed 18 out 240 images
# Processed 19 out 240 images
# Processed 20 out 240 images
# Processed 21 out 240 images
# Processed 22 out 240 images
# Processed 23 out 240 images
# Processed 24 out 240 images
# Processed 25 out 240 images
# Processed 26 out 240 images
# Processed 27 out 240 images
# Processed 28 out 240 images
# Processed 29 out 240 images
# Processed 30 out 240 images
# Processed 31 out 240 images
# Processed 32 out 240 images
# Processed 33 out 240 images
# Processed 34 out 240 images
# Processed 35 out 240 images
# Processed 36 out 240 images
# Processed 37 out 240 images
# Processed 38 out 240 images
# Processed 39 out 240 images
# Processed 40 out 240 images
# Processed 41 out 240 images
# Processed 42 out 240 images
# Processed 43 out 240 images
# Processed 44 out 240 images
# Processed 45 out 240 images
# Processed 46 out 240 images
# Processed 47 out 240 images
# Processed 48 out 240 images
# Processed 49 out 240 images
# Processed 50 out 240 images
# Processed 51 out 240 images
# Processed 52 out 240 images
# Processed 53 out 240 images
# Processed 54 out 240 images
# Processed 55 out 240 images
# Processed 56 out 240 images
# Processed 57 out 240 images
# Processed 58 out 240 images
# Processed 59 out 240 images
# Processed 60 out 240 images
# Processed 61 out 240 images
# Processed 62 out 240 images
# Processed 63 out 240 images
# Processed 64 out 240 images
# Processed 65 out 240 images
# Processed 66 out 240 images
# Processed 67 out 240 images
# Processed 68 out 240 images
# Processed 69 out 240 images
# Processed 70 out 240 images
# Processed 71 out 240 images
# Processed 72 out 240 images
# Processed 73 out 240 images
# Processed 74 out 240 images
# Processed 75 out 240 images
# Processed 76 out 240 images
# Processed 77 out 240 images
# Processed 78 out 240 images
# Processed 79 out 240 images
# Processed 80 out 240 images
# Processed 81 out 240 images
# Processed 82 out 240 images
# Processed 83 out 240 images
# Processed 84 out 240 images
# Processed 85 out 240 images
# Processed 86 out 240 images
# Processed 87 out 240 images
# Processed 88 out 240 images
# Processed 89 out 240 images
# Processed 90 out 240 images
# Processed 91 out 240 images
# Processed 92 out 240 images
# Processed 93 out 240 images
# Processed 94 out 240 images
# Processed 95 out 240 images
# Processed 96 out 240 images
# Processed 97 out 240 images
# Processed 98 out 240 images
# Processed 99 out 240 images
# Processed 100 out 240 images
# Processed 101 out 240 images
# Processed 102 out 240 images
# Processed 103 out 240 images
# Processed 104 out 240 images
# Processed 105 out 240 images
# Processed 106 out 240 images
# Processed 107 out 240 images
# Processed 108 out 240 images
# Processed 109 out 240 images
# Processed 110 out 240 images
# Processed 111 out 240 images
# Processed 112 out 240 images
# Processed 113 out 240 images
# Processed 114 out 240 images
# Processed 115 out 240 images
# Processed 116 out 240 images
# Processed 117 out 240 images
# Processed 118 out 240 images
# Processed 119 out 240 images
# Processed 120 out 240 images
# Processed 121 out 240 images
# Processed 122 out 240 images
# Processed 123 out 240 images
# Processed 124 out 240 images
# Processed 125 out 240 images
# Processed 126 out 240 images
# Processed 127 out 240 images
# Processed 128 out 240 images
# Processed 129 out 240 images
# Processed 130 out 240 images
# Processed 131 out 240 images
# Processed 132 out 240 images
# Processed 133 out 240 images
# Processed 134 out 240 images
# Processed 136 out 240 images
# Processed 137 out 240 images
# Processed 138 out 240 images
# Processed 139 out 240 images
# Processed 140 out 240 images
# Processed 141 out 240 images
# Processed 142 out 240 images
# Processed 143 out 240 images
# Processed 144 out 240 images
# Processed 145 out 240 images
# Processed 146 out 240 images
# Processed 147 out 240 images
# Processed 148 out 240 images
# Processed 149 out 240 images
# Processed 150 out 240 images
# Processed 151 out 240 images
# Processed 152 out 240 images
# Processed 153 out 240 images
# Processed 154 out 240 images
# Processed 155 out 240 images
# Processed 156 out 240 images
# Processed 157 out 240 images
# Processed 158 out 240 images
# Processed 159 out 240 images
# Processed 160 out 240 images
# Processed 161 out 240 images
# Processed 162 out 240 images
# Processed 163 out 240 images
# Processed 164 out 240 images
# Processed 165 out 240 images
# Processed 166 out 240 images
# Processed 167 out 240 images
# Processed 168 out 240 images
# Processed 169 out 240 images
# Processed 170 out 240 images
# Processed 171 out 240 images
# Processed 172 out 240 images
# Processed 173 out 240 images
# Processed 174 out 240 images
# Processed 175 out 240 images
# Processed 176 out 240 images
# Processed 177 out 240 images
# Processed 178 out 240 images
# Processed 179 out 240 images
# Processed 180 out 240 images
# Processed 181 out 240 images
# Processed 182 out 240 images
# Processed 183 out 240 images
# Processed 184 out 240 images
# Processed 185 out 240 images
# Processed 186 out 240 images
# Processed 187 out 240 images
# Processed 188 out 240 images
# Processed 189 out 240 images
# Processed 190 out 240 images
# Processed 191 out 240 images
# Processed 192 out 240 images
# Processed 193 out 240 images
# Processed 194 out 240 images
# Processed 195 out 240 images
# Processed 196 out 240 images
# Processed 197 out 240 images
# Processed 198 out 240 images
# Processed 199 out 240 images
# Processed 200 out 240 images
# Processed 201 out 240 images
# Processed 202 out 240 images
# Processed 203 out 240 images
# Processed 204 out 240 images
# Processed 205 out 240 images
# Processed 206 out 240 images
# Processed 207 out 240 images
# Processed 208 out 240 images
# Processed 209 out 240 images
# Processed 210 out 240 images
# Processed 211 out 240 images
# Processed 212 out 240 images
# Processed 213 out 240 images
# Processed 214 out 240 images
# Processed 215 out 240 images
# Processed 216 out 240 images
# Processed 217 out 240 images
# Processed 218 out 240 images
# Processed 219 out 240 images
# Processed 220 out 240 images
# Processed 221 out 240 images
# Processed 222 out 240 images
# Processed 223 out 240 images
# Processed 224 out 240 images
# Processed 225 out 240 images
# Processed 226 out 240 images
# Processed 227 out 240 images
# Processed 228 out 240 images
# Processed 229 out 240 images
# Processed 230 out 240 images
# Processed 231 out 240 images
# Processed 232 out 240 images
# Processed 233 out 240 images
# Processed 234 out 240 images
# Processed 235 out 240 images
# Processed 236 out 240 images
# Processed 237 out 240 images
# Processed 238 out 240 images
# Processed 239 out 240 images
# Processed 1 out 60 images
# Processed 2 out 60 images
# Processed 3 out 60 images
# Processed 4 out 60 images
# Processed 5 out 60 images
# Processed 6 out 60 images
# Processed 7 out 60 images
# Processed 8 out 60 images
# Processed 9 out 60 images
# Processed 10 out 60 images
# Processed 11 out 60 images
# Processed 12 out 60 images
# Processed 13 out 60 images
# Processed 14 out 60 images
# Processed 15 out 60 images
# Processed 16 out 60 images
# Processed 17 out 60 images
# Processed 18 out 60 images
# Processed 19 out 60 images
# Processed 20 out 60 images
# Processed 21 out 60 images
# Processed 22 out 60 images
# Processed 23 out 60 images
# Processed 24 out 60 images
# Processed 25 out 60 images
# Processed 26 out 60 images
# Processed 27 out 60 images
# Processed 28 out 60 images
# Processed 29 out 60 images
# Processed 30 out 60 images
# Processed 31 out 60 images
# Processed 32 out 60 images
# Processed 33 out 60 images
# Processed 34 out 60 images
# Processed 35 out 60 images
# Processed 36 out 60 images
# Processed 37 out 60 images
# Processed 38 out 60 images
# Processed 39 out 60 images
# Processed 40 out 60 images
# Processed 41 out 60 images
# Processed 42 out 60 images
# Processed 43 out 60 images
# Processed 44 out 60 images
# Processed 45 out 60 images
# Processed 46 out 60 images
# Processed 47 out 60 images
# Processed 48 out 60 images
# Processed 49 out 60 images
# Processed 50 out 60 images
# Processed 51 out 60 images
# Processed 52 out 60 images
# Processed 53 out 60 images
# Processed 54 out 60 images
# Processed 55 out 60 images
# Processed 56 out 60 images
# Processed 57 out 60 images
# Processed 58 out 60 images
# Processed 59 out 60 images
# Shape of training features (238, 224, 224, 3)
# Shape of training coordinates (238, 4)
# shape of training labels (238, 3)
# Shape of validation features (59, 224, 224, 3)
# Shape of validation coordinates (59, 4)
# shape of validation labels (59, 3)

# %%
#validating the resized annotation by visualisation
for i in range(5):
  fig,ax = plt.subplots()
  fig.suptitle("Label".format(train_labels[i]), fontsize=10)
  ax.imshow(train_features[i])
  xA,yA,xB,yB = train_coordinates[i]
  rect = patches.Rectangle((xA,yA),xB-xA,yB-yA, linewidth=1, edgecolor='r',facecolor='none')
  ax.add_patch(rect)

# %%
# !nvidia-smi
# Out:
# Mon Mar  1 10:01:08 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#creating model architecture
def MobileNetv1(input_shape, n_coor, number_classes):
   #depth wise convolution block definition
    def depthwise_convolutionBlock(InputTensor, pointwise_filter_size, stride):
    #Depthwise layer
        x = DepthwiseConv2D(3,stride,padding='same')(InputTensor)
        x = BatchNormalization()(x)
        x = ReLU()(x)
        #Pointwise layer
        x = Conv2D(pointwise_filter_size,1)(x)
        x = BatchNormalization()(x)
        x = ReLU()(x)
        return x

    Model_input = Input(input_shape)
    x = Conv2D(32,3,2,padding='same')(Model_input)
    #Batch normalisation and ReLU activation after each convolution are mandatory for non-linearity and avoiding co-variance shift
    x = BatchNormalization()(x)
    x = ReLU()(x)
    print(x)
    #now stacking depthwise conv block as per Mobilenet paper
    x = depthwise_convolutionBlock(x,64,1)
    print(x)
    x = depthwise_convolutionBlock(x,128,2)
    x = Dropout(0.2)(x)
    x = depthwise_convolutionBlock(x,128,1)
    x = depthwise_convolutionBlock(x,256,2)
    x = Dropout(0.2)(x)
    x = depthwise_convolutionBlock(x,256,1)
    x = Dropout(0.2)(x)
    x = depthwise_convolutionBlock(x,512,2)
    for i in range(5):
        x = depthwise_convolutionBlock(x,512,1)
        x = depthwise_convolutionBlock(x,1024,1)
        x = depthwise_convolutionBlock(x,1024,1)
    #Adding average pooling 2D layer
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.2)(x)
    #4 coordinates
    bbox_coordinates = Dense(4, activation = 'linear', name = 'regressor')(x)
    #x = GlobalAveragePooling2D()
    # full connected i.e dense layer
    logits = Dense(number_classes, activation='softmax', name='classifier')(x)
    
    model = Model(inputs = Model_input, outputs = [bbox_coordinates,logits])
    return model

# %%
Input_shape = 224,224,3
num_classes = 3
n_coor = 4
model = MobileNetv1(Input_shape,n_coor,num_classes)
model.summary()
#dense_6 is the output of regression:: bbox end
# dense_7 is the output of classification end
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 112, 112, 32), dtype=tf.float32, name=None), name='re_lu_48/Relu:0', description="created by layer 're_lu_48'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 112, 112, 64), dtype=tf.float32, name=None), name='re_lu_50/Relu:0', description="created by layer 're_lu_50'")
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 112, 112, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 112, 112, 32) 128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, 112, 112, 32) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_23 (DepthwiseC (None, 112, 112, 32) 320         re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 112, 112, 32) 128         depthwise_conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_49 (ReLU)                 (None, 112, 112, 32) 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 112, 112, 64) 2112        re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 112, 112, 64) 256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, 112, 112, 64) 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_24 (DepthwiseC (None, 56, 56, 64)   640         re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 56, 56, 64)   256         depthwise_conv2d_24[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, 56, 56, 64)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 56, 56, 128)  8320        re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 56, 56, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_52 (ReLU)                 (None, 56, 56, 128)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 56, 56, 128)  0           re_lu_52[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_25 (DepthwiseC (None, 56, 56, 128)  1280        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 56, 56, 128)  512         depthwise_conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_53 (ReLU)                 (None, 56, 56, 128)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 56, 56, 128)  16512       re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 56, 56, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# re_lu_54 (ReLU)                 (None, 56, 56, 128)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_26 (DepthwiseC (None, 28, 28, 128)  1280        re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 28, 28, 128)  512         depthwise_conv2d_26[0][0]
# __________________________________________________________________________________________________
# re_lu_55 (ReLU)                 (None, 28, 28, 128)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 256)  33024       re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 28, 28, 256)  1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_56 (ReLU)                 (None, 28, 28, 256)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 28, 28, 256)  0           re_lu_56[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_27 (DepthwiseC (None, 28, 28, 256)  2560        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 28, 28, 256)  1024        depthwise_conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_57 (ReLU)                 (None, 28, 28, 256)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 28, 28, 256)  65792       re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 28, 28, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_58 (ReLU)                 (None, 28, 28, 256)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 28, 28, 256)  0           re_lu_58[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_28 (DepthwiseC (None, 14, 14, 256)  2560        dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 14, 14, 256)  1024        depthwise_conv2d_28[0][0]
# __________________________________________________________________________________________________
# re_lu_59 (ReLU)                 (None, 14, 14, 256)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 512)  131584      re_lu_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 14, 14, 512)  2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_60 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_29 (DepthwiseC (None, 14, 14, 512)  5120        re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 14, 14, 512)  2048        depthwise_conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_61 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 512)  262656      re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 14, 14, 512)  2048        conv2d_32[0][0]
# __________________________________________________________________________________________________
# re_lu_62 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_30 (DepthwiseC (None, 14, 14, 512)  5120        re_lu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 14, 14, 512)  2048        depthwise_conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_63 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 1024) 525312      re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 14, 14, 1024) 4096        conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_64 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_31 (DepthwiseC (None, 14, 14, 1024) 10240       re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 14, 14, 1024) 4096        depthwise_conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_65 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 1024) 1049600     re_lu_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 14, 14, 1024) 4096        conv2d_34[0][0]
# __________________________________________________________________________________________________
# re_lu_66 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_32 (DepthwiseC (None, 14, 14, 1024) 10240       re_lu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 14, 14, 1024) 4096        depthwise_conv2d_32[0][0]
# __________________________________________________________________________________________________
# re_lu_67 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 512)  524800      re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 14, 14, 512)  2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# re_lu_68 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_33 (DepthwiseC (None, 14, 14, 512)  5120        re_lu_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 14, 14, 512)  2048        depthwise_conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_69 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 1024) 525312      re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 14, 14, 1024) 4096        conv2d_36[0][0]
# __________________________________________________________________________________________________
# re_lu_70 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_34 (DepthwiseC (None, 14, 14, 1024) 10240       re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 14, 14, 1024) 4096        depthwise_conv2d_34[0][0]
# __________________________________________________________________________________________________
# re_lu_71 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 1024) 1049600     re_lu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 14, 14, 1024) 4096        conv2d_37[0][0]
# __________________________________________________________________________________________________
# re_lu_72 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_35 (DepthwiseC (None, 14, 14, 1024) 10240       re_lu_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 14, 14, 1024) 4096        depthwise_conv2d_35[0][0]
# __________________________________________________________________________________________________
# re_lu_73 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 512)  524800      re_lu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 14, 14, 512)  2048        conv2d_38[0][0]
# __________________________________________________________________________________________________
# re_lu_74 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_36 (DepthwiseC (None, 14, 14, 512)  5120        re_lu_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 14, 14, 512)  2048        depthwise_conv2d_36[0][0]
# __________________________________________________________________________________________________
# re_lu_75 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 1024) 525312      re_lu_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 14, 14, 1024) 4096        conv2d_39[0][0]
# __________________________________________________________________________________________________
# re_lu_76 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_37 (DepthwiseC (None, 14, 14, 1024) 10240       re_lu_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 14, 14, 1024) 4096        depthwise_conv2d_37[0][0]
# __________________________________________________________________________________________________
# re_lu_77 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 1024) 1049600     re_lu_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 14, 14, 1024) 4096        conv2d_40[0][0]
# __________________________________________________________________________________________________
# re_lu_78 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_38 (DepthwiseC (None, 14, 14, 1024) 10240       re_lu_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 14, 14, 1024) 4096        depthwise_conv2d_38[0][0]
# __________________________________________________________________________________________________
# re_lu_79 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 512)  524800      re_lu_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 14, 14, 512)  2048        conv2d_41[0][0]
# __________________________________________________________________________________________________
# re_lu_80 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_39 (DepthwiseC (None, 14, 14, 512)  5120        re_lu_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 14, 14, 512)  2048        depthwise_conv2d_39[0][0]
# __________________________________________________________________________________________________
# re_lu_81 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 1024) 525312      re_lu_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 14, 14, 1024) 4096        conv2d_42[0][0]
# __________________________________________________________________________________________________
# re_lu_82 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_40 (DepthwiseC (None, 14, 14, 1024) 10240       re_lu_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 14, 14, 1024) 4096        depthwise_conv2d_40[0][0]
# __________________________________________________________________________________________________
# re_lu_83 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 1024) 1049600     re_lu_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 14, 14, 1024) 4096        conv2d_43[0][0]
# __________________________________________________________________________________________________
# re_lu_84 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_41 (DepthwiseC (None, 14, 14, 1024) 10240       re_lu_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 14, 14, 1024) 4096        depthwise_conv2d_41[0][0]
# __________________________________________________________________________________________________
# re_lu_85 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 512)  524800      re_lu_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 14, 14, 512)  2048        conv2d_44[0][0]
# __________________________________________________________________________________________________
# re_lu_86 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_42 (DepthwiseC (None, 14, 14, 512)  5120        re_lu_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 14, 14, 512)  2048        depthwise_conv2d_42[0][0]
# __________________________________________________________________________________________________
# re_lu_87 (ReLU)                 (None, 14, 14, 512)  0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 1024) 525312      re_lu_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 14, 14, 1024) 4096        conv2d_45[0][0]
# __________________________________________________________________________________________________
# re_lu_88 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_43 (DepthwiseC (None, 14, 14, 1024) 10240       re_lu_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 14, 14, 1024) 4096        depthwise_conv2d_43[0][0]
# __________________________________________________________________________________________________
# re_lu_89 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 1024) 1049600     re_lu_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 14, 14, 1024) 4096        conv2d_46[0][0]
# __________________________________________________________________________________________________
# re_lu_90 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1024)         0           re_lu_90[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1024)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# regressor (Dense)               (None, 4)            4100        dropout_3[0][0]
# __________________________________________________________________________________________________
# classifier (Dense)              (None, 3)            3075        dropout_3[0][0]
# ==================================================================================================
# Total params: 10,742,663
# Trainable params: 10,688,007
# Non-trainable params: 54,656
# __________________________________________________________________________________________________

# %%
#compiling model with loss functions
init_lr = 0.0001
epochs = 100
opt = Adam(lr=init_lr, decay=init_lr / epochs)
model.compile(optimizer=opt, 
              loss={'regressor':'mse','classifier':'categorical_crossentropy'}, 
              metrics={'regressor':'accuracy','classifier':'accuracy'})

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
callbacks = [ModelCheckpoint("/content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint", monitor='val_loss')]
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
model.fit(train_features,[train_coordinates,train_labels],batch_size = 1,epochs = 100,verbose=1,callbacks=[callbacks], validation_data=(val_features, [val_coordinates,val_labels]),shuffle=True, validation_batch_size=32 ,use_multiprocessing=True,workers=12 )
# Out:
# Epoch 1/100
# 238/238 [==============================] - 10s 26ms/step - loss: 23357.4932 - regressor_loss: 23356.3227 - classifier_loss: 1.1666 - regressor_accuracy: 0.1901 - classifier_accuracy: 0.2627 - val_loss: 24499.3770 - val_regressor_loss: 24498.2695 - val_classifier_loss: 1.1091 - val_regressor_accuracy: 0.2881 - val_classifier_accuracy: 0.3220
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets
# Epoch 2/100
# 238/238 [==============================] - 5s 22ms/step - loss: 21769.8268 - regressor_loss: 21768.6943 - classifier_loss: 1.1328 - regressor_accuracy: 0.7122 - classifier_accuracy: 0.3181 - val_loss: 21591.2109 - val_regressor_loss: 21589.8750 - val_classifier_loss: 1.3376 - val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.3220
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets
# Epoch 3/100
# 238/238 [==============================] - 5s 23ms/step - loss: 19270.8740 - regressor_loss: 19269.7539 - classifier_loss: 1.1248 - regressor_accuracy: 0.7258 - classifier_accuracy: 0.3904 - val_loss: 17623.7734 - val_regressor_loss: 17622.4023 - val_classifier_loss: 1.3706 - val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.3220
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets
# Epoch 4/100
# 238/238 [==============================] - 5s 22ms/step - loss: 16028.8058 - regressor_loss: 16027.6146 - classifier_loss: 1.1930 - regressor_accuracy: 0.7488 - classifier_accuracy: 0.3354 - val_loss: 16794.8164 - val_regressor_loss: 16793.6738 - val_classifier_loss: 1.1420 - val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.3220
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets
# Epoch 5/100
# 238/238 [==============================] - 5s 23ms/step - loss: 14822.5574 - regressor_loss: 14821.4043 - classifier_loss: 1.1497 - regressor_accuracy: 0.7301 - classifier_accuracy: 0.3965 - val_loss: 13984.2754 - val_regressor_loss: 13983.1143 - val_classifier_loss: 1.1613 - val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.
- val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.3559
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets
# Epoch 95/100
# 238/238 [==============================] - 5s 23ms/step - loss: 2269.7515 - regressor_loss: 2268.6102 - classifier_loss: 1.1407 - regressor_accuracy: 0.7894 - classifier_accuracy: 0.3447 - val_loss: 6178.0786 - val_regressor_loss: 6176.9702 - val_classifier_loss: 1.1079 - val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.3559
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets
# Epoch 96/100
# 238/238 [==============================] - 6s 23ms/step - loss: 1530.1360 - regressor_loss: 1528.9671 - classifier_loss: 1.1685 - regressor_accuracy: 0.7675 - classifier_accuracy: 0.3425 - val_loss: 5677.7236 - val_regressor_loss: 5676.6313 - val_classifier_loss: 1.0921 - val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.4068
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets
# Epoch 97/100
# 238/238 [==============================] - 5s 23ms/step - loss: 1651.2032 - regressor_loss: 1650.0634 - classifier_loss: 1.1399 - regressor_accuracy: 0.7632 - classifier_accuracy: 0.4035 - val_loss: 5363.5620 - val_regressor_loss: 5362.4805 - val_classifier_loss: 1.0816 - val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.3559
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets
# Epoch 98/100
# 238/238 [==============================] - 5s 23ms/step - loss: 1481.8988 - regressor_loss: 1480.7470 - classifier_loss: 1.1517 - regressor_accuracy: 0.7232 - classifier_accuracy: 0.3494 - val_loss: 5079.3940 - val_regressor_loss: 5078.3130 - val_classifier_loss: 1.0807 - val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.4068
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets
# Epoch 99/100
# 238/238 [==============================] - 6s 23ms/step - loss: 1570.7625 - regressor_loss: 1569.6242 - classifier_loss: 1.1386 - regressor_accuracy: 0.7645 - classifier_accuracy: 0.3876 - val_loss: 5565.3076 - val_regressor_loss: 5564.2134 - val_classifier_loss: 1.0941 - val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.3898
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets
# Epoch 100/100
# 238/238 [==============================] - 5s 23ms/step - loss: 1679.0004 - regressor_loss: 1677.8830 - classifier_loss: 1.1175 - regressor_accuracy: 0.7832 - classifier_accuracy: 0.4364 - val_loss: 5705.9946 - val_regressor_loss: 5704.8296 - val_classifier_loss: 1.1648 - val_regressor_accuracy: 0.7119 - val_classifier_accuracy: 0.3559
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Dataset/checkpoint/assets

# %%
#saving the model
model.save("FruitDetector.h5")

# %% [markdown]
# ### 2. Inference Stage.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8cdc0cfb-2e3f-46d0-9e29-a826936d56d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8cdc0cfb-2e3f-46d0-9e29-a826936d56d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test4.jpg to Test4.jpg
# Saving Test3.jpg to Test3.jpg
# Saving Test1.jpg to Test1.jpg
# Saving Test2.jpg to Test2 (1).jpg

# %%
#prediction stage
image_list = []
image_list.append('Test1.jpg')
image_list.append('Test2.jpg')
image_list.append('Test3.jpg')
image_list.append('Test4.jpg')
for orig_image in image_list:
  print(orig_image)
  orig_image = cv2.imread(orig_image)
  image = cv2.resize(orig_image,(224,224),interpolation = cv2.INTER_AREA)
  image = np.reshape(image,(1,224,224,3))
  #np.shape(image))
  out_tensor = model.predict(image)
  #finding the class_label
  LabelDict = {0:"apple",1:"banana", 2:"orange"}
  class_label = LabelDict[np.argmax(out_tensor[1])]
  xA,yA,xB,yB= out_tensor[0][0]
  #visualising
  fig,ax = plt.subplots()
  fig.suptitle("Predicted Label is {}".format(class_label), fontsize=10)
  ax.imshow(orig_image)
  rect = patches.Rectangle((xA,yA),xB-xA,yB-yA, linewidth=1, edgecolor='r',facecolor='none')
  ax.add_patch(rect)
# Out:
# Test1.jpg
# Test2.jpg
# Test3.jpg
# Test4.jpg

# %%
# Out:
# 1
